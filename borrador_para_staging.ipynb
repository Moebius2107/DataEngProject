# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
hackatons = pd.read_csv(r"C:\Users\Usuario\Data Engineering insa\final_project\DataEngProject\csv_data\customer_db\hackatons.csv")
print(hackatons.head())
# Out:
#                         _id  \
# 0  637cf0e0b6e321016d07f0b6
# 1  637cf0e0b6e321016d07f0b7
# 2  637cf0e0b6e321016d07f0b8
# 3  637cf0e0b6e321016d07f0b9
# 4  637cf0e0b6e321016d07f0ba
#
#                           hackathon-description-text  \
# 0  \nNew York State’s Metropolitan Transit Author...
# 1  \nWhat would you do with real-time GTFS data f...
# 2  \n現代城市面臨眾多巨變和挑戰：氣候變遷、人口老化所帶來的衝擊，以及大眾運輸、都市更新引發的...
# 3                \nExpedia is hosting a hackathon at
# 4  \nLove creating stuff on your computer and LOV...
#
#    hackathon-number-of-prizes                    hackathon-id  \
# 0                           9                 2013mtaappquest
# 1                          10                 2014mtaappquest
# 2                           3                     2015hackntu
# 3                           3  2016-expedia-hackathon-chicago
# 4                          11             2016baseballhackday
#
#               hackathon-judges.0.judge-role hackathon-judges.0.judge-name  \
# 0  Senior Director of Capital Programs, MTA                 Craig Stewart
# 1                President of AT&T New York           Marissa Shorenstein
# 2                                       NaN                       HackNTU
# 3                 Senior Director / Expedia                 Pascal Collet
# 4                        MLB Advanced Media                 Staff members
#
#         hackathon-judges.1.judge-role hackathon-judges.1.judge-name  \
# 0          President of AT&T New York           Marissa Shorenstein
# 1  Chief Data Officer, New York State               Barbara L. Cohn
# 2                                 NaN                           NaN
# 3           Senior Director / Expedia                Ryan Kowalczyk
# 4                                 NaN                           NaN
#
#                        hackathon-judges.2.judge-role  \
# 0                          NYC Chief Digital Officer
# 1                                      TechnoBuffalo
# 2                                                NaN
# 3  Director, Technology, Strategic Initiatives Ca...
# 4                                                NaN
#
#   hackathon-judges.2.judge-name  ...  \
# 0                   Rachel Haot  ...
# 1                 Todd Haselton  ...
# 2                           NaN  ...
# 3            Philippe Deschenes  ...
# 4                           NaN  ...
#
#   hackathon-judging-criteria.6.judging-criterion  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   hackathon-judging-criteria.7.judging-criterion  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   hackathon-judging-criteria.8.judging-criterion  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   hackathon-judging-criteria.9.judging-criterion  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                      hackathon-location-address  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3  20 N Upper Wacker Dr, Chicago, IL 60606, USA
# 4                                           NaN
#
#                         hackathon-description-header hackathon-prizes-total  \
# 0  See how developers changed the way 8.5 million...                $50,000
# 1  More data. More connectivity. More smartphone ...                $50,000
# 2           Create any topic you would like to hack!                $10,675
# 3                Create apps to revolutionize travel                 $8,000
# 4  Fun, friendly, free, one-day, on-site hacking/...                 $7,040
#
#                       hackathon-location-description hackathon-end-date  \
# 0                                                NaN         2014-03-24
# 1                                                NaN         2015-02-03
# 2                                                NaN                NaN
# 3                                          TechNexus                NaN
# 4  5 locations: Boston, Philadelphia, Montreal, C...         2016-03-19
#
#   has-projects
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#
# [5 rows x 130 columns]

# %%
participants = pd.read_csv(r"C:\Users\Usuario\Data Engineering insa\final_project\DataEngProject\csv_data\customer_db\participants.csv")
print(participants.head())
# Out:
#                         _id  participant-likes  participant-projects  \
# 0  637cf0e0db0b0ee0254416e7                  1                     2
# 1  637cf0e0db0b0ee0254416e8                  0                     1
# 2  637cf0e0db0b0ee0254416e9                  0                     3
# 3  637cf0e0db0b0ee0254416ea                  0                     1
# 4  637cf0e0db0b0ee0254416eb                  2                     5
#
#                   participant-url participant-name  participant-followers  \
# 0      https://devpost.com/4n3ver        Yoel Ivan                      1
# 1       https://devpost.com/88250       Liang Ding                      2
# 2  https://devpost.com/aaronkoons      Aaron Koons                      1
# 3   https://devpost.com/Ab3PHilip   Abraham Philip                      1
# 4  https://devpost.com/abeSanchez      abe sanchez                      0
#
#                  participant-location participant-bio participant-id  \
# 0                     Atlanta, GA, US             NaN         4n3ver
# 1              Kunming, Yunnan, China             NaN          88250
# 2  Rochester, New York, United States             NaN     aaronkoons
# 3  Exton, Pennsylvania, United States             NaN      Ab3PHilip
# 4     Orlando, Florida, United States             NaN     abeSanchez
#
#                    participant-linkedin  ... participant-skills.18.name  \
# 0  https://www.linkedin.com/in/yoelivan  ...                        NaN
# 1                                   NaN  ...                        NaN
# 2                                   NaN  ...                        NaN
# 3                                   NaN  ...                        NaN
# 4                                   NaN  ...                        NaN
#
#   participant-skills.19.url  participant-skills.19.name  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    participant-skills.20.url  participant-skills.20.name  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   participant-skills.21.url participant-skills.21.name  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   participant-skills.22.url participant-skills.22.name participant-twitter
# 0                       NaN                        NaN                 NaN
# 1                       NaN                        NaN                 NaN
# 2                       NaN                        NaN                 NaN
# 3                       NaN                        NaN                 NaN
# 4                       NaN                        NaN                 NaN
#
# [5 rows x 62 columns]

# %%
projects = pd.read_csv(r"C:\Users\Usuario\Data Engineering insa\final_project\DataEngProject\csv_data\customer_db\projects.csv")
print(projects.head())
# Out:
#                         _id hackathon-id  hackathon-winner  \
# 0  637cf0e069d39c94132a81d9          NaN             False
# 1  637cf0e069d39c94132a81da  sdhacks2017             False
# 2  637cf0e069d39c94132a81db          NaN             False
# 3  637cf0e069d39c94132a81dc       mhacks             False
# 4  637cf0e069d39c94132a81dd  2017circles             False
#
#    project-technologies-used  \
# 0                          0
# 1                          4
# 2                          2
# 3                          0
# 4                          0
#
#                                        project-video project-basis  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4  https://www.youtube.com/embed/00yGYjJtHog?enab...           NaN
#
#                       project-technologies.0.url project-technologies.0.name  \
# 0                                            NaN                         NaN
# 1   https://devpost.com/software/built-with/html                        html
# 2  https://devpost.com/software/built-with/ionic                       ionic
# 3                                            NaN                         NaN
# 4                                            NaN                         NaN
#
#                           project-technologies.1.url  \
# 0                                                NaN
# 1     https://devpost.com/software/built-with/python
# 2  https://devpost.com/software/built-with/angula...
# 3                                                NaN
# 4                                                NaN
#
#   project-technologies.1.name  ... team.5.participant-desc  \
# 0                         NaN  ...                     NaN
# 1                      python  ...                     NaN
# 2                  angular.js  ...                     NaN
# 3                         NaN  ...                     NaN
# 4                         NaN  ...                     NaN
#
#   team.5.participant-url team.5.participant-id team.6.participant-bubble  \
# 0                    NaN                   NaN                       NaN
# 1                    NaN                   NaN                       NaN
# 2                    NaN                   NaN                       NaN
# 3                    NaN                   NaN                       NaN
# 4                    NaN                   NaN                       NaN
#
#   team.6.participant-name team.6.participant-desc team.6.participant-url  \
# 0                     NaN                     NaN                    NaN
# 1                     NaN                     NaN                    NaN
# 2                     NaN                     NaN                    NaN
# 3                     NaN                     NaN                    NaN
# 4                     NaN                     NaN                    NaN
#
#   team.6.participant-id                                        project-url  \
# 0                   NaN                https://devpost.com/software/-5une2
# 1                   NaN                 https://devpost.com/software/14all
# 2                   NaN             https://devpost.com/software/1504scout
# 3                   NaN            https://devpost.com/software/27-minutes
# 4                   NaN  https://devpost.com/software/360-live-vr-robotics
#
#              project-id
# 0                -5une2
# 1                 14all
# 2             1504scout
# 3            27-minutes
# 4  360-live-vr-robotics
#
# [5 rows x 90 columns]

# %%
hackatons.sample(5)
# Out:
#                           _id  \
# 187  637cf0e2b6e321016d07f171
# 364  637cf0e4b6e321016d07f222
# 428  637cf0e4b6e321016d07f262
# 754  637cf207869826b131a512c0
# 365  637cf0e4b6e321016d07f223
#
#                             hackathon-description-text  \
# 187                            \n10:00AM  Registration
# 364  \nBuild anything at all - we have a bunch of h...
# 428  \nA hackathon is where you turn your crazy ide...
# 754  \nHackTheU is Utah's most innovative hackathon...
# 365                                                 \n
#
#      hackathon-number-of-prizes hackathon-id hackathon-judges.0.judge-role  \
# 187                           3     hackdrew                     Professor
# 364                           8       oxhack                        OxHACK
# 428                           1  startupucsd                          UCSD
# 754                           8     hacktheu                 The Void, CVO
# 365                           6    packhacks                           NaN
#
#     hackathon-judges.0.judge-name            hackathon-judges.1.judge-role  \
# 187                    Emily Hill                                Professor
# 364                 Taimur Abdaal                                   OxHACK
# 428                Martin Arreola  NSF I-Corps Program Coordinator at UCSD
# 754                  James Jensen                        MD, PhD, MPH, MBA
# 365                      Ziad Ali                                      NaN
#
#     hackathon-judges.1.judge-name  \
# 187                    Barry Burd
# 364                     James May
# 428                   Jay Gilberg
# 754                  John Langell
# 365                           NaN
#
#                          hackathon-judges.2.judge-role  \
# 187                                                NaN
# 364                                           Mendeley
# 428  Managing Director, Research Translation Group ...
# 754                            Morph3D, AR/VR Director
# 365                                                NaN
#
#     hackathon-judges.2.judge-name  ...  \
# 187                           NaN  ...
# 364                   Joyce Stack  ...
# 428                     Jay Kunin  ...
# 754                  Chris Madsen  ...
# 365                           NaN  ...
#
#     hackathon-judging-criteria.6.judging-criterion  \
# 187                                            NaN
# 364                                            NaN
# 428                                            NaN
# 754                                            NaN
# 365                                            NaN
#
#     hackathon-judging-criteria.7.judging-criterion  \
# 187                                            NaN
# 364                                            NaN
# 428                                            NaN
# 754                                            NaN
# 365                                            NaN
#
#     hackathon-judging-criteria.8.judging-criterion  \
# 187                                            NaN
# 364                                            NaN
# 428                                            NaN
# 754                                            NaN
# 365                                            NaN
#
#     hackathon-judging-criteria.9.judging-criterion  \
# 187                                            NaN
# 364                                            NaN
# 428                                            NaN
# 754                                            NaN
# 365                                            NaN
#
#                             hackathon-location-address  \
# 187             36 Madison Ave, Madison, NJ 07940, USA
# 364                       Saïd Business School, Oxford
# 428           9730 Hopkins Dr, La Jolla, CA 92093, USA
# 754  1701 Student Life Way, Salt Lake City, UT 8411...
# 365  Engineering Bldg II, 890 Oval Dr, Raleigh, NC ...
#
#                           hackathon-description-header hackathon-prizes-total  \
# 187  Create awesome applications with software or h...                   $150
# 364                     Oxford's first ever hackathon.                 $2,347
# 428                         Make something people want                $18,000
# 754       HackTheU is Utah's most innovative hackathon                 $5,620
# 365                              NC State's Hackathon!                 $2,170
#
#                    hackathon-location-description hackathon-end-date  \
# 187           Drew University- Learning Center 28         2017-04-23
# 364                                           NaN         2014-11-30
# 428           University of California, San Diego         2016-05-14
# 754          University of Utah, Lassonde Studios         2016-11-13
# 365  NC State Unversity - Engineering Building II         2018-04-22
#
#     has-projects
# 187         True
# 364         True
# 428         True
# 754         True
# 365         True
#
# [5 rows x 130 columns]

# %%
hackatons.describe()
# Out:
#        hackathon-number-of-prizes  hackathon-number-of-judges  \
# count                  1000.00000                 1000.000000
# mean                      6.62600                    4.544000
# std                       5.81377                    4.204967
# min                       1.00000                    0.000000
# 25%                       3.00000                    1.000000
# 50%                       5.00000                    4.000000
# 75%                       8.25000                    6.000000
# max                      39.00000                   28.000000
#
#        hackathon-number-of-judging-criteria  \
# count                           1000.000000
# mean                               3.458000
# std                                1.714402
# min                                0.000000
# 25%                                2.000000
# 50%                                4.000000
# 75%                                4.000000
# max                               10.000000
#
#        hackathon-judging-criteria.9.judging-criterion
# count                                             0.0
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN

# %%
hackatons.columns
# Out:
# Index(['_id', 'hackathon-description-text', 'hackathon-number-of-prizes',
#        'hackathon-id', 'hackathon-judges.0.judge-role',
#        'hackathon-judges.0.judge-name', 'hackathon-judges.1.judge-role',
#        'hackathon-judges.1.judge-name', 'hackathon-judges.2.judge-role',
#        'hackathon-judges.2.judge-name',
#        ...
#        'hackathon-judging-criteria.6.judging-criterion',
#        'hackathon-judging-criteria.7.judging-criterion',
#        'hackathon-judging-criteria.8.judging-criterion',
#        'hackathon-judging-criteria.9.judging-criterion',
#        'hackathon-location-address', 'hackathon-description-header',
#        'hackathon-prizes-total', 'hackathon-location-description',
#        'hackathon-end-date', 'has-projects'],
#       dtype='object', length=130)

# %%
### Handling duplicates

# %%
dupes = hackatons.duplicated()
dupes
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
dupes1 dupes1
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data_1 = data_1.drop_duplicates()
data_1.shape

# %%
### Handling Missing Data

# %%
data_1.isnull().sum()

# %%
#Now we are going to work with participants

# %%
participants_pandas = pd.DataFrame(list(participants.find()))

# %%
participants_pandas.sample(10)
# Out:
#                          _id  \
# 40  6378fabf0c32f46426b7f561
# 7   6378e6ba0c32f46426b7f529
# 14  6378e6ba0c32f46426b7f530
# 42  6378fabf0c32f46426b7f563
# 23  6378f45a0c32f46426b7f53c
# 56  6378fabf0c32f46426b7f571
# 59  6378fabf0c32f46426b7f574
# 65  6378fabf0c32f46426b7f57a
# 46  6378fabf0c32f46426b7f567
# 45  6378fabf0c32f46426b7f566
#
#                            hackathon-description-text  \
# 40                                                NaN
# 7                                                 \n
# 14  \nJoin us for our 1st annual Android Summit Ha...
# 42                                                NaN
# 23  \nLove creating stuff on your computer and LOV...
# 56                                                NaN
# 59                                                NaN
# 65                                                NaN
# 46                                                NaN
# 45                                                NaN
#
#    hackathon-number-of-prizes              hackathon-id  \
# 40                        NaN                       NaN
# 7                           4                   a4s2015
# 14                          3  android-summit-hackathon
# 42                        NaN                       NaN
# 23                         11       2016baseballhackday
# 56                        NaN                       NaN
# 59                        NaN                       NaN
# 65                        NaN                       NaN
# 46                        NaN                       NaN
# 45                        NaN                       NaN
#
#                                      hackathon-judges  \
# 40                                                NaN
# 7   [{'judge-role': 'AFT', 'judge-name': 'Vincent ...
# 14     [{'judge-role': '', 'judge-name': 'Hackers!'}]
# 42                                                NaN
# 23  [{'judge-role': 'MLB Advanced Media', 'judge-n...
# 56                                                NaN
# 59                                                NaN
# 65                                                NaN
# 46                                                NaN
# 45                                                NaN
#
#    hackathon-number-of-judges  \
# 40                        NaN
# 7                           1
# 14                          1
# 42                        NaN
# 23                          1
# 56                        NaN
# 59                        NaN
# 65                        NaN
# 46                        NaN
# 45                        NaN
#
#                                 hackathon-eligibility  \
# 40                                                NaN
# 7
# 14  \nMust sign up through EventBrite registration...
# 42                                                NaN
# 23  \nTo be eligible, you do need to be on-site at...
# 56                                                NaN
# 59                                                NaN
# 65                                                NaN
# 46                                                NaN
# 45                                                NaN
#
#    hackathon-number-of-participants hackathon-is-colocated  \
# 40                              NaN                    NaN
# 7                                16                   True
# 14                               32                   True
# 42                              NaN                    NaN
# 23                               61                   True
# 56                              NaN                    NaN
# 59                              NaN                    NaN
# 65                              NaN                    NaN
# 46                              NaN                    NaN
# 45                              NaN                    NaN
#
#    hackathon-has-ended  ...  \
# 40                 NaN  ...
# 7                 True  ...
# 14                True  ...
# 42                 NaN  ...
# 23                True  ...
# 56                 NaN  ...
# 59                 NaN  ...
# 65                 NaN  ...
# 46                 NaN  ...
# 45                 NaN  ...
#
#                                       participant-bio participant-id  \
# 40                                                        aaronkoons
# 7                                                 NaN            NaN
# 14                                                NaN            NaN
# 42                                                        abeSanchez
# 23                                                NaN            NaN
# 56                                                       ahmedbekhit
# 59                                                             aldyl
# 65  ''Perhaps I was too saucy and provoking''\n-Be...          alugo
# 46                                                          achow101
# 45                                                      abrar-sammia
#
#                       participant-linkedin  \
# 40
# 7                                      NaN
# 14                                     NaN
# 42
# 23                                     NaN
# 56
# 59
# 65
# 46
# 45  https://ca.linkedin.com/in/sammiaabrar
#
#                    participant-website  \
# 40
# 7                                  NaN
# 14                                 NaN
# 42      https://github.com/abe-sanchez
# 23                                 NaN
# 56             http://ahmedbekhit.com/
# 59
# 65  http://alugocp.github.io/webdesign
# 46                 http://achow101.com
# 45      http://sammia-abrar.tumblr.com
#
#                                    participant-github participant-hackathons  \
# 40                                                                         3
# 7                                                 NaN                    NaN
# 14                                                NaN                    NaN
# 42                     https://github.com/abe-sanchez                      4
# 23                                                NaN                    NaN
# 56                          https://github.com/AFathi                      9
# 59  https://github.com/https://github.com/aldyleon...                      1
# 65                         https://github.com/alugocp                      1
# 46                        https://github.com/achow101                      2
# 45                    https://github.com/abrar-sammia                      1
#
#    participant-following participant-number-of-skills  \
# 40                     3                            2
# 7                    NaN                          NaN
# 14                   NaN                          NaN
# 42                     3                            8
# 23                   NaN                          NaN
# 56                     2                            4
# 59                     3                            4
# 65                     3                            5
# 46                     0                            5
# 45                     4                            0
#
#                                    participant-skills  \
# 40  [{'url': 'https://devpost.com/software/built-w...
# 7                                                 NaN
# 14                                                NaN
# 42  [{'url': 'https://devpost.com/software/built-w...
# 23                                                NaN
# 56  [{'url': 'https://devpost.com/software/built-w...
# 59  [{'url': 'https://devpost.com/software/built-w...
# 65  [{'url': 'https://devpost.com/software/built-w...
# 46  [{'url': 'https://devpost.com/software/built-w...
# 45                                                 []
#
#             participant-twitter
# 40
# 7                           NaN
# 14                          NaN
# 42
# 23                          NaN
# 56
# 59
# 65  https://twitter.com/alugocp
# 46
# 45
#
# [10 rows x 39 columns]

# %%
participants_pandas.describe()
# Out:
#                              _id  \
# count                         68
# unique                        68
# top     6378e6ba0c32f46426b7f522
# freq                           1
#
#                                hackathon-description-text  \
# count                                                  38
# unique                                                 19
# top     \nNew York State’s Metropolitan Transit Author...
# freq                                                    2
#
#        hackathon-number-of-prizes     hackathon-id  \
# count                          38               38
# unique                          9               19
# top                             3  2013mtaappquest
# freq                           10                2
#
#                                          hackathon-judges  \
# count                                                  38
# unique                                                 19
# top     [{'judge-role': 'Senior Director of Capital Pr...
# freq                                                    2
#
#        hackathon-number-of-judges hackathon-eligibility  \
# count                          38                    38
# unique                          8                    14
# top                             1
# freq                           16                    12
#
#        hackathon-number-of-participants hackathon-is-colocated  \
# count                                38                     38
# unique                               17                      2
# top                                  61                   True
# freq                                  4                     22
#
#        hackathon-has-ended  ... participant-bio participant-id  \
# count                   38  ...              30             30
# unique                   2  ...               8             30
# top                   True  ...                         4n3ver
# freq                    26  ...              23              1
#
#        participant-linkedin participant-website participant-github  \
# count                    30                  30                 30
# unique                   11                  22                 20
# top
# freq                     20                   9                 11
#
#        participant-hackathons participant-following  \
# count                      30                    30
# unique                      7                     8
# top                         1                     0
# freq                       13                    16
#
#        participant-number-of-skills participant-skills participant-twitter
# count                            30                 30                  30
# unique                           14                 27                   8
# top                               2                 []
# freq                              4                  4                  23
#
# [4 rows x 39 columns]

# %%
participants_pandas.columns
# Out:
# Index(['_id', 'hackathon-description-text', 'hackathon-number-of-prizes',
#        'hackathon-id', 'hackathon-judges', 'hackathon-number-of-judges',
#        'hackathon-eligibility', 'hackathon-number-of-participants',
#        'hackathon-is-colocated', 'hackathon-has-ended',
#        'hackathon-number-of-judging-criteria', 'hackathon-requirements',
#        'hackathon-rules', 'hackathon-prizes', 'hackathon-location-google-maps',
#        'hackathon-url', 'hackathon-judging-criteria',
#        'hackathon-location-address', 'hackathon-description-header',
#        'hackathon-prizes-total', 'hackathon-location-description',
#        'hackathon-end-date', 'has-projects', 'participant-likes',
#        'participant-projects', 'participant-url', 'participant-name',
#        'participant-followers', 'participant-location', 'participant-bio',
#        'participant-id', 'participant-linkedin', 'participant-website',
#        'participant-github', 'participant-hackathons', 'participant-following',
#        'participant-number-of-skills', 'participant-skills',
#        'participant-twitter'],
#       dtype='object')

# %%
# # # We can observe that some of the columns have compound information, e.g. Body Dimension and Body weight. Also, some records have meaningless data. Also, some columns are irrelevant to the analysis, like the Picture url.
# # # So, we will do the following.
# # # - Drop irrelevant columns, e.g. Picture url
# # # - Drop records with meaningless data. We can drop records for which columns like Body dimensions, Body weight and display resolution are less than 20 characters long.

# %%
data_2 = data_2.drop('Picture URL small', axis =1)
data_2.columns

# %%
data_2 = data_2.rename (columns = {'Body Dimensions':'BodyDimensions', 'Body Weight':'BodyWeight', 'Display Resolution':'DisplayResolution'})
data_2.dtypes

# %%
data_2.info()
#data_2.info(memory_usage='deep')

# %%
#We can observe that Pandas is not able to infer the type on its own for the non-ID columns. So, let's enforce the type

# %%
data_2['Brand']= data_2['Brand'].astype('str')
data_2['Phone']= data_2['Phone'].astype('str')
data_2['BodyDimensions']= data_2['BodyDimensions'].astype('str')
data_2['BodyWeight']= data_2['BodyWeight'].astype('str')
data_2['DisplayResolution']= data_2['DisplayResolution'].astype('str')

# %%
price_ranges = pd.read_csv('./data/input/price_ranges.csv', header=0, names=['price_range', 'Min', 'Max'])

joined_data = (final_data_1
               .join(final_data_2,how='inner')
               .join(price_ranges,how='inner',on='price_range',rsuffix='_r')
              )

joined_data.head()

# %%
joined_data.shape

# %%
joined_data.to_csv('./data/output/ready_for_analysis.csv')
