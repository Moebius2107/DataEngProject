# %%
import pandas as pd
from matplotlib import pyplot as plt
pd.options.display.max_columns = None

# %%
hackatons = pd.read_csv(r"C:\Users\Usuario\Data Engineering insa\project_borrador\data\hackatons.csv")

# %%
###we are going to analyze Hackatons
hackatons.shape
# Out:
# (2349, 164)

# %%
hackatons.sample(2)
# Out:
#                            _id  \
# 1142  63854467343173ef37d0451a
# 2237  63854470343173ef37d04961
#
#                              hackathon-description-text  \
# 1142  \nHackSmith is Smith College’s annual hackatho...
# 2237  \nThe Vistara Hackathon brings India's Largest...
#
#       hackathon-number-of-prizes                 hackathon-id  \
# 1142                           6                  hacksmith18
# 2237                           3  vistara-hackathon-bangalore
#
#      hackathon-judges.0.judge-role hackathon-judges.0.judge-name  \
# 1142   CS Professor, Smith College            Dominique Thiebaut
# 2237                         Adobe             Supreeth Nagaraju
#
#      hackathon-judges.1.judge-role hackathon-judges.1.judge-name  \
# 1142   CS Professor, Smith College                 Nicholas Howe
# 2237                        Amazon                 Samir Karande
#
#                 hackathon-judges.2.judge-role hackathon-judges.2.judge-name  \
# 1142  Technical Staff, MIT Lincoln Laboratory                David Whelihan
# 2237                         Vistara Airlines            Ravinder Pal Singh
#
#      hackathon-judges.3.judge-role hackathon-judges.3.judge-name  \
# 1142      Director, GlowLime Games                 Joel Esquilin
# 2237                           NaN                           NaN
#
#      hackathon-judges.4.judge-role hackathon-judges.4.judge-name  \
# 1142       Director, Conway Center                   Monica Dean
# 2237                           NaN                           NaN
#
#      hackathon-judges.5.judge-role hackathon-judges.5.judge-name  \
# 1142                           NaN                           NaN
# 2237                           NaN                           NaN
#
#      hackathon-judges.6.judge-role hackathon-judges.6.judge-name  \
# 1142                           NaN                           NaN
# 2237                           NaN                           NaN
#
#      hackathon-judges.7.judge-role hackathon-judges.7.judge-name  \
# 1142                           NaN                           NaN
# 2237                           NaN                           NaN
#
#      hackathon-judges.8.judge-role hackathon-judges.8.judge-name  \
# 1142                           NaN                           NaN
# 2237                           NaN                           NaN
#
#      hackathon-judges.9.judge-role hackathon-judges.9.judge-name  \
# 1142                           NaN                           NaN
# 2237                           NaN                           NaN
#
#      hackathon-judges.10.judge-role hackathon-judges.10.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.11.judge-role hackathon-judges.11.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.12.judge-role hackathon-judges.12.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.13.judge-role hackathon-judges.13.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.14.judge-role hackathon-judges.14.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.15.judge-role hackathon-judges.15.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.16.judge-role hackathon-judges.16.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.17.judge-role hackathon-judges.17.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.18.judge-role hackathon-judges.18.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.19.judge-role hackathon-judges.19.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.20.judge-role hackathon-judges.20.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.21.judge-role hackathon-judges.21.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.22.judge-role hackathon-judges.22.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.23.judge-role hackathon-judges.23.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.24.judge-role hackathon-judges.24.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.25.judge-role hackathon-judges.25.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.26.judge-role hackathon-judges.26.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.27.judge-role hackathon-judges.27.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.28.judge-role hackathon-judges.28.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.29.judge-role hackathon-judges.29.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.30.judge-role hackathon-judges.30.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.31.judge-role hackathon-judges.31.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.32.judge-role hackathon-judges.32.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.33.judge-role hackathon-judges.33.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.34.judge-role hackathon-judges.34.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.35.judge-role hackathon-judges.35.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.36.judge-role hackathon-judges.36.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.37.judge-role hackathon-judges.37.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.38.judge-role hackathon-judges.38.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.39.judge-role hackathon-judges.39.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.40.judge-role hackathon-judges.40.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#      hackathon-judges.41.judge-role hackathon-judges.41.judge-name  \
# 1142                            NaN                            NaN
# 2237                            NaN                            NaN
#
#       hackathon-number-of-judges  \
# 1142                           5
# 2237                           3
#
#                                   hackathon-eligibility  \
# 1142  \nAll participants must either be currently pu...
# 2237                             \n\nMinimum age is 18
#
#      hackathon-number-of-participants  hackathon-is-colocated  \
# 1142                               14                    True
# 2237                              104                    True
#
#       hackathon-has-ended  hackathon-number-of-judging-criteria  \
# 1142                False                                     4
# 2237                False                                     4
#
#                      hackathon-requirements  \
# 1142                                    NaN
# 2237  \nSubmission must be done by 12:30 Pm
#
#                                         hackathon-rules  \
# 1142  \nBecause we want to create a safe environment...
# 2237  \n\nThis is a team participation hackathon. Th...
#
#      hackathon-prizes.0.prize-content  \
# 1142                              NaN
# 2237                              NaN
#
#                          hackathon-prizes.0.prize-title  \
# 1142                                  Best Overall Hack
# 2237  1st Prize    - Mobile Phones  - Amazon Firesti...
#
#      hackathon-prizes.1.prize-content  \
# 1142                              NaN
# 2237                              NaN
#
#                          hackathon-prizes.1.prize-title  \
# 1142                               Best First Time Hack
# 2237  2nd Prize   - Amazon Kindle to every team memb...
#
#      hackathon-prizes.2.prize-content  \
# 1142                              NaN
# 2237                              NaN
#
#                          hackathon-prizes.2.prize-title  \
# 1142                                          Best Game
# 2237  3rd Prize   - Smart Fitness Watch to each memb...
#
#      hackathon-prizes.3.prize-content hackathon-prizes.3.prize-title  \
# 1142                              NaN                Best Mobile App
# 2237                              NaN                            NaN
#
#      hackathon-prizes.4.prize-content hackathon-prizes.4.prize-title  \
# 1142                              NaN                   Best Web App
# 2237                              NaN                            NaN
#
#      hackathon-prizes.5.prize-content     hackathon-prizes.5.prize-title  \
# 1142                              NaN  Most Innovative Business Solution
# 2237                              NaN                                NaN
#
#      hackathon-prizes.6.prize-content hackathon-prizes.6.prize-title  \
# 1142                              NaN                            NaN
# 2237                              NaN                            NaN
#
#      hackathon-prizes.7.prize-content hackathon-prizes.7.prize-title  \
# 1142                              NaN                            NaN
# 2237                              NaN                            NaN
#
#      hackathon-prizes.8.prize-content hackathon-prizes.8.prize-title  \
# 1142                              NaN                            NaN
# 2237                              NaN                            NaN
#
#      hackathon-prizes.9.prize-content hackathon-prizes.9.prize-title  \
# 1142                              NaN                            NaN
# 2237                              NaN                            NaN
#
#      hackathon-prizes.10.prize-content hackathon-prizes.10.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.11.prize-content hackathon-prizes.11.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.12.prize-content hackathon-prizes.12.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.13.prize-content hackathon-prizes.13.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.14.prize-content hackathon-prizes.14.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.15.prize-content hackathon-prizes.15.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.16.prize-content hackathon-prizes.16.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.17.prize-content hackathon-prizes.17.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.18.prize-content hackathon-prizes.18.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.19.prize-content hackathon-prizes.19.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.20.prize-content hackathon-prizes.20.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.21.prize-content hackathon-prizes.21.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.22.prize-content hackathon-prizes.22.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.23.prize-content hackathon-prizes.23.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.24.prize-content hackathon-prizes.24.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#      hackathon-prizes.25.prize-content hackathon-prizes.25.prize-title  \
# 1142                               NaN                             NaN
# 2237                               NaN                             NaN
#
#                          hackathon-location-google-maps  \
# 1142  https://maps.google.com/?q=Smith College Campu...
# 2237  https://maps.google.com/?q=Unit 02-01 & 27, Se...
#
#                                          hackathon-url  \
# 1142                  https://hacksmith18.devpost.com/
# 2237  https://vistara-hackathon-bangalore.devpost.com/
#
#      hackathon-judging-criteria.0.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.1.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.2.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.3.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.4.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.5.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.6.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#      hackathon-judging-criteria.7.judging-criterion  \
# 1142                                            NaN
# 2237                                            NaN
#
#                              hackathon-location-address  \
# 1142  Smith College Campus Center, 100 Elm St, North...
# 2237  Unit 02-01 & 27, Second Floor, Ascendas Park, ...
#
#                  hackathon-description-header hackathon-prizes-total  \
# 1142                    Championing Diversity                   $755
# 2237  India's Largest Aviation Hackathon 2017                      0
#
#      hackathon-location-description hackathon-end-date  has-projects
# 1142   Campus Center, Smith College                NaN         False
# 2237                         Kstart                NaN         False

# %%
hackatons.columns.tolist()
# Out:
# ['_id',
#  'hackathon-description-text',
#  'hackathon-number-of-prizes',
#  'hackathon-id',
#  'hackathon-judges.0.judge-role',
#  'hackathon-judges.0.judge-name',
#  'hackathon-judges.1.judge-role',
#  'hackathon-judges.1.judge-name',
#  'hackathon-judges.2.judge-role',
#  'hackathon-judges.2.judge-name',
#  'hackathon-judges.3.judge-role',
#  'hackathon-judges.3.judge-name',
#  'hackathon-judges.4.judge-role',
#  'hackathon-judges.4.judge-name',
#  'hackathon-judges.5.judge-role',
#  'hackathon-judges.5.judge-name',
#  'hackathon-judges.6.judge-role',
#  'hackathon-judges.6.judge-name',
#  'hackathon-judges.7.judge-role',
#  'hackathon-judges.7.judge-name',
#  'hackathon-judges.8.judge-role',
#  'hackathon-judges.8.judge-name',
#  'hackathon-judges.9.judge-role',
#  'hackathon-judges.9.judge-name',
#  'hackathon-judges.10.judge-role',
#  'hackathon-judges.10.judge-name',
#  'hackathon-judges.11.judge-role',
#  'hackathon-judges.11.judge-name',
#  'hackathon-judges.12.judge-role',
#  'hackathon-judges.12.judge-name',
#  'hackathon-judges.13.judge-role',
#  'hackathon-judges.13.judge-name',
#  'hackathon-judges.14.judge-role',
#  'hackathon-judges.14.judge-name',
#  'hackathon-judges.15.judge-role',
#  'hackathon-judges.15.judge-name',
#  'hackathon-judges.16.judge-role',
#  'hackathon-judges.16.judge-name',
#  'hackathon-judges.17.judge-role',
#  'hackathon-judges.17.judge-name',
#  'hackathon-judges.18.judge-role',
#  'hackathon-judges.18.judge-name',
#  'hackathon-judges.19.judge-role',
#  'hackathon-judges.19.judge-name',
#  'hackathon-judges.20.judge-role',
#  'hackathon-judges.20.judge-name',
#  'hackathon-judges.21.judge-role',
#  'hackathon-judges.21.judge-name',
#  'hackathon-judges.22.judge-role',
#  'hackathon-judges.22.judge-name',
#  'hackathon-judges.23.judge-role',
#  'hackathon-judges.23.judge-name',
#  'hackathon-judges.24.judge-role',
#  'hackathon-judges.24.judge-name',
#  'hackathon-judges.25.judge-role',
#  'hackathon-judges.25.judge-name',
#  'hackathon-judges.26.judge-role',
#  'hackathon-judges.26.judge-name',
#  'hackathon-judges.27.judge-role',
#  'hackathon-judges.27.judge-name',
#  'hackathon-judges.28.judge-role',
#  'hackathon-judges.28.judge-name',
#  'hackathon-judges.29.judge-role',
#  'hackathon-judges.29.judge-name',
#  'hackathon-judges.30.judge-role',
#  'hackathon-judges.30.judge-name',
#  'hackathon-judges.31.judge-role',
#  'hackathon-judges.31.judge-name',
#  'hackathon-judges.32.judge-role',
#  'hackathon-judges.32.judge-name',
#  'hackathon-judges.33.judge-role',
#  'hackathon-judges.33.judge-name',
#  'hackathon-judges.34.judge-role',
#  'hackathon-judges.34.judge-name',
#  'hackathon-judges.35.judge-role',
#  'hackathon-judges.35.judge-name',
#  'hackathon-judges.36.judge-role',
#  'hackathon-judges.36.judge-name',
#  'hackathon-judges.37.judge-role',
#  'hackathon-judges.37.judge-name',
#  'hackathon-judges.38.judge-role',
#  'hackathon-judges.38.judge-name',
#  'hackathon-judges.39.judge-role',
#  'hackathon-judges.39.judge-name',
#  'hackathon-judges.40.judge-role',
#  'hackathon-judges.40.judge-name',
#  'hackathon-judges.41.judge-role',
#  'hackathon-judges.41.judge-name',
#  'hackathon-number-of-judges',
#  'hackathon-eligibility',
#  'hackathon-number-of-participants',
#  'hackathon-is-colocated',
#  'hackathon-has-ended',
#  'hackathon-number-of-judging-criteria',
#  'hackathon-requirements',
#  'hackathon-rules',
#  'hackathon-prizes.0.prize-content',
#  'hackathon-prizes.0.prize-title',
#  'hackathon-prizes.1.prize-content',
#  'hackathon-prizes.1.prize-title',
#  'hackathon-prizes.2.prize-content',
#  'hackathon-prizes.2.prize-title',
#  'hackathon-prizes.3.prize-content',
#  'hackathon-prizes.3.prize-title',
#  'hackathon-prizes.4.prize-content',
#  'hackathon-prizes.4.prize-title',
#  'hackathon-prizes.5.prize-content',
#  'hackathon-prizes.5.prize-title',
#  'hackathon-prizes.6.prize-content',
#  'hackathon-prizes.6.prize-title',
#  'hackathon-prizes.7.prize-content',
#  'hackathon-prizes.7.prize-title',
#  'hackathon-prizes.8.prize-content',
#  'hackathon-prizes.8.prize-title',
#  'hackathon-prizes.9.prize-content',
#  'hackathon-prizes.9.prize-title',
#  'hackathon-prizes.10.prize-content',
#  'hackathon-prizes.10.prize-title',
#  'hackathon-prizes.11.prize-content',
#  'hackathon-prizes.11.prize-title',
#  'hackathon-prizes.12.prize-content',
#  'hackathon-prizes.12.prize-title',
#  'hackathon-prizes.13.prize-content',
#  'hackathon-prizes.13.prize-title',
#  'hackathon-prizes.14.prize-content',
#  'hackathon-prizes.14.prize-title',
#  'hackathon-prizes.15.prize-content',
#  'hackathon-prizes.15.prize-title',
#  'hackathon-prizes.16.prize-content',
#  'hackathon-prizes.16.prize-title',
#  'hackathon-prizes.17.prize-content',
#  'hackathon-prizes.17.prize-title',
#  'hackathon-prizes.18.prize-content',
#  'hackathon-prizes.18.prize-title',
#  'hackathon-prizes.19.prize-content',
#  'hackathon-prizes.19.prize-title',
#  'hackathon-prizes.20.prize-content',
#  'hackathon-prizes.20.prize-title',
#  'hackathon-prizes.21.prize-content',
#  'hackathon-prizes.21.prize-title',
#  'hackathon-prizes.22.prize-content',
#  'hackathon-prizes.22.prize-title',
#  'hackathon-prizes.23.prize-content',
#  'hackathon-prizes.23.prize-title',
#  'hackathon-prizes.24.prize-content',
#  'hackathon-prizes.24.prize-title',
#  'hackathon-prizes.25.prize-content',
#  'hackathon-prizes.25.prize-title',
#  'hackathon-location-google-maps',
#  'hackathon-url',
#  'hackathon-judging-criteria.0.judging-criterion',
#  'hackathon-judging-criteria.1.judging-criterion',
#  'hackathon-judging-criteria.2.judging-criterion',
#  'hackathon-judging-criteria.3.judging-criterion',
#  'hackathon-judging-criteria.4.judging-criterion',
#  'hackathon-judging-criteria.5.judging-criterion',
#  'hackathon-judging-criteria.6.judging-criterion',
#  'hackathon-judging-criteria.7.judging-criterion',
#  'hackathon-location-address',
#  'hackathon-description-header',
#  'hackathon-prizes-total',
#  'hackathon-location-description',
#  'hackathon-end-date',
#  'has-projects']

# %%
### Handling duplicates

# %%
duplicate = hackatons[hackatons.duplicated(['hackathon-id', 'hackathon-description-text', 'hackathon-number-of-participants', 'hackathon-end-date'])]
duplicate
# Out:
# Empty DataFrame
# Columns: [_id, hackathon-description-text, hackathon-number-of-prizes, hackathon-id, hackathon-judges.0.judge-role, hackathon-judges.0.judge-name, hackathon-judges.1.judge-role, hackathon-judges.1.judge-name, hackathon-judges.2.judge-role, hackathon-judges.2.judge-name, hackathon-judges.3.judge-role, hackathon-judges.3.judge-name, hackathon-judges.4.judge-role, hackathon-judges.4.judge-name, hackathon-judges.5.judge-role, hackathon-judges.5.judge-name, hackathon-judges.6.judge-role, hackathon-judges.6.judge-name, hackathon-judges.7.judge-role, hackathon-judges.7.judge-name, hackathon-judges.8.judge-role, hackathon-judges.8.judge-name, hackathon-judges.9.judge-role, hackathon-judges.9.judge-name, hackathon-judges.10.judge-role, hackathon-judges.10.judge-name, hackathon-judges.11.judge-role, hackathon-judges.11.judge-name, hackathon-judges.12.judge-role, hackathon-judges.12.judge-name, hackathon-judges.13.judge-role, hackathon-judges.13.judge-name, hackathon-judges.14.judge-role, hackathon-judges.14.judge-name, hackathon-judges.15.judge-role, hackathon-judges.15.judge-name, hackathon-judges.16.judge-role, hackathon-judges.16.judge-name, hackathon-judges.17.judge-role, hackathon-judges.17.judge-name, hackathon-judges.18.judge-role, hackathon-judges.18.judge-name, hackathon-judges.19.judge-role, hackathon-judges.19.judge-name, hackathon-judges.20.judge-role, hackathon-judges.20.judge-name, hackathon-judges.21.judge-role, hackathon-judges.21.judge-name, hackathon-judges.22.judge-role, hackathon-judges.22.judge-name, hackathon-judges.23.judge-role, hackathon-judges.23.judge-name, hackathon-judges.24.judge-role, hackathon-judges.24.judge-name, hackathon-judges.25.judge-role, hackathon-judges.25.judge-name, hackathon-judges.26.judge-role, hackathon-judges.26.judge-name, hackathon-judges.27.judge-role, hackathon-judges.27.judge-name, hackathon-judges.28.judge-role, hackathon-judges.28.judge-name, hackathon-judges.29.judge-role, hackathon-judges.29.judge-name, hackathon-judges.30.judge-role, hackathon-judges.30.judge-name, hackathon-judges.31.judge-role, hackathon-judges.31.judge-name, hackathon-judges.32.judge-role, hackathon-judges.32.judge-name, hackathon-judges.33.judge-role, hackathon-judges.33.judge-name, hackathon-judges.34.judge-role, hackathon-judges.34.judge-name, hackathon-judges.35.judge-role, hackathon-judges.35.judge-name, hackathon-judges.36.judge-role, hackathon-judges.36.judge-name, hackathon-judges.37.judge-role, hackathon-judges.37.judge-name, hackathon-judges.38.judge-role, hackathon-judges.38.judge-name, hackathon-judges.39.judge-role, hackathon-judges.39.judge-name, hackathon-judges.40.judge-role, hackathon-judges.40.judge-name, hackathon-judges.41.judge-role, hackathon-judges.41.judge-name, hackathon-number-of-judges, hackathon-eligibility, hackathon-number-of-participants, hackathon-is-colocated, hackathon-has-ended, hackathon-number-of-judging-criteria, hackathon-requirements, hackathon-rules, hackathon-prizes.0.prize-content, hackathon-prizes.0.prize-title, hackathon-prizes.1.prize-content, hackathon-prizes.1.prize-title, ...]
# Index: []

# %%
#We are going to remove duplicates bases on 'hackathon-id' and'hackathon-number-of-participants' because it will make a¡our analyzis wrong.

# %%
unique_hack = hackatons.drop_duplicates(subset="hackathon-id", keep='first')
unique_hack.shape
# Out:
# (2349, 164)

# %%
### Handling Missing Data

# %%
nulls = unique_hack.isnull().sum()
for key,value in nulls.items():
    print(key,",",value)
# Out:
# _id , 0
# hackathon-description-text , 0
# hackathon-number-of-prizes , 0
# hackathon-id , 0
# hackathon-judges.0.judge-role , 664
# hackathon-judges.0.judge-name , 26
# hackathon-judges.1.judge-role , 882
# hackathon-judges.1.judge-name , 676
# hackathon-judges.2.judge-role , 975
# hackathon-judges.2.judge-name , 798
# hackathon-judges.3.judge-role , 1220
# hackathon-judges.3.judge-name , 1083
# hackathon-judges.4.judge-role , 1500
# hackathon-judges.4.judge-name , 1399
# hackathon-judges.5.judge-role , 1770
# hackathon-judges.5.judge-name , 1700
# hackathon-judges.6.judge-role , 1942
# hackathon-judges.6.judge-name , 1892
# hackathon-judges.7.judge-role , 2052
# hackathon-judges.7.judge-name , 2013
# hackathon-judges.8.judge-role , 2117
# hackathon-judges.8.judge-name , 2087
# hackathon-judges.9.judge-role , 2176
# hackathon-judges.9.judge-name , 2151
# hackathon-judges.10.judge-role , 2208
# hackathon-judges.10.judge-name , 2187
# hackathon-judges.11.judge-role , 2237
# hackathon-judges.11.judge-name , 2220
# hackathon-judges.12.judge-role , 2254
# hackathon-judges.12.judge-name , 2239
# hackathon-judges.13.judge-role , 2266
# hackathon-judges.13.judge-name , 2253
# hackathon-judges.14.judge-role , 2278
# hackathon-judges.14.judge-name , 2269
# hackathon-judges.15.judge-role , 2290
# hackathon-judges.15.judge-name , 2281
# hackathon-judges.16.judge-role , 2300
# hackathon-judges.16.judge-name , 2293
# hackathon-judges.17.judge-role , 2308
# hackathon-judges.17.judge-name , 2301
# hackathon-judges.18.judge-role , 2317
# hackathon-judges.18.judge-name , 2311
# hackathon-judges.19.judge-role , 2325
# hackathon-judges.19.judge-name , 2320
# hackathon-judges.20.judge-role , 2326
# hackathon-judges.20.judge-name , 2322
# hackathon-judges.21.judge-role , 2327
# hackathon-judges.21.judge-name , 2322
# hackathon-judges.22.judge-role , 2330
# hackathon-judges.22.judge-name , 2325
# hackathon-judges.23.judge-role , 2332
# hackathon-judges.23.judge-name , 2329
# hackathon-judges.24.judge-role , 2336
# hackathon-judges.24.judge-name , 2331
# hackathon-judges.25.judge-role , 2337
# hackathon-judges.25.judge-name , 2332
# hackathon-judges.26.judge-role , 2338
# hackathon-judges.26.judge-name , 2333
# hackathon-judges.27.judge-role , 2339
# hackathon-judges.27.judge-name , 2336
# hackathon-judges.28.judge-role , 2340
# hackathon-judges.28.judge-name , 2338
# hackathon-judges.29.judge-role , 2341
# hackathon-judges.29.judge-name , 2339
# hackathon-judges.30.judge-role , 2341
# hackathon-judges.30.judge-name , 2339
# hackathon-judges.31.judge-role , 2343
# hackathon-judges.31.judge-name , 2341
# hackathon-judges.32.judge-role , 2343
# hackathon-judges.32.judge-name , 2341
# hackathon-judges.33.judge-role , 2344
# hackathon-judges.33.judge-name , 2342
# hackathon-judges.34.judge-role , 2344
# hackathon-judges.34.judge-name , 2342
# hackathon-judges.35.judge-role , 2344
# hackathon-judges.35.judge-name , 2342
# hackathon-judges.36.judge-role , 2344
# hackathon-judges.36.judge-name , 2342
# hackathon-judges.37.judge-role , 2345
# hackathon-judges.37.judge-name , 2343
# hackathon-judges.38.judge-role , 2345
# hackathon-judges.38.judge-name , 2344
# hackathon-judges.39.judge-role , 2345
# hackathon-judges.39.judge-name , 2344
# hackathon-judges.40.judge-role , 2345
# hackathon-judges.40.judge-name , 2344
# hackathon-judges.41.judge-role , 2346
# hackathon-judges.41.judge-name , 2344
# hackathon-number-of-judges , 0
# hackathon-eligibility , 891
# hackathon-number-of-participants , 0
# hackathon-is-colocated , 0
# hackathon-has-ended , 0
# hackathon-number-of-judging-criteria , 0
# hackathon-requirements , 1053
# hackathon-rules , 313
# hackathon-prizes.0.prize-content , 657
# hackathon-prizes.0.prize-title , 3
# hackathon-prizes.1.prize-content , 852
# hackathon-prizes.1.prize-title , 293
# hackathon-prizes.2.prize-content , 950
# hackathon-prizes.2.prize-title , 459
# hackathon-prizes.3.prize-content , 1162
# hackathon-prizes.3.prize-title , 857
# hackathon-prizes.4.prize-content , 1352
# hackathon-prizes.4.prize-title , 1129
# hackathon-prizes.5.prize-content , 1481
# hackathon-prizes.5.prize-title , 1333
# hackathon-prizes.6.prize-content , 1614
# hackathon-prizes.6.prize-title , 1491
# hackathon-prizes.7.prize-content , 1724
# hackathon-prizes.7.prize-title , 1624
# hackathon-prizes.8.prize-content , 1808
# hackathon-prizes.8.prize-title , 1726
# hackathon-prizes.9.prize-content , 1882
# hackathon-prizes.9.prize-title , 1811
# hackathon-prizes.10.prize-content , 1950
# hackathon-prizes.10.prize-title , 1901
# hackathon-prizes.11.prize-content , 2006
# hackathon-prizes.11.prize-title , 1961
# hackathon-prizes.12.prize-content , 2054
# hackathon-prizes.12.prize-title , 2024
# hackathon-prizes.13.prize-content , 2111
# hackathon-prizes.13.prize-title , 2081
# hackathon-prizes.14.prize-content , 2154
# hackathon-prizes.14.prize-title , 2128
# hackathon-prizes.15.prize-content , 2183
# hackathon-prizes.15.prize-title , 2161
# hackathon-prizes.16.prize-content , 2210
# hackathon-prizes.16.prize-title , 2190
# hackathon-prizes.17.prize-content , 2233
# hackathon-prizes.17.prize-title , 2215
# hackathon-prizes.18.prize-content , 2247
# hackathon-prizes.18.prize-title , 2232
# hackathon-prizes.19.prize-content , 2263
# hackathon-prizes.19.prize-title , 2254
# hackathon-prizes.20.prize-content , 2276
# hackathon-prizes.20.prize-title , 2269
# hackathon-prizes.21.prize-content , 2281
# hackathon-prizes.21.prize-title , 2277
# hackathon-prizes.22.prize-content , 2291
# hackathon-prizes.22.prize-title , 2286
# hackathon-prizes.23.prize-content , 2301
# hackathon-prizes.23.prize-title , 2297
# hackathon-prizes.24.prize-content , 2307
# hackathon-prizes.24.prize-title , 2302
# hackathon-prizes.25.prize-content , 2317
# hackathon-prizes.25.prize-title , 2312
# hackathon-location-google-maps , 484
# hackathon-url , 0
# hackathon-judging-criteria.0.judging-criterion , 716
# hackathon-judging-criteria.1.judging-criterion , 948
# hackathon-judging-criteria.2.judging-criterion , 1003
# hackathon-judging-criteria.3.judging-criterion , 1321
# hackathon-judging-criteria.4.judging-criterion , 1885
# hackathon-judging-criteria.5.judging-criterion , 2158
# hackathon-judging-criteria.6.judging-criterion , 2262
# hackathon-judging-criteria.7.judging-criterion , 2310
# hackathon-location-address , 484
# hackathon-description-header , 0
# hackathon-prizes-total , 0
# hackathon-location-description , 805
# hackathon-end-date , 604
# has-projects , 0

# %%
#we don't have to delete any row because of nulls because in the columns we care they don't have nulls

# %%
#we are going to drop some unusefull columns for our analysis

# %%
final_hackaton=unique_hack.dropna(axis=1).copy()
final_hackaton.shape
# Out:
# (2349, 13)

# %%
final_hackaton['hackathon-location-address'] = unique_hack['hackathon-location-address']
final_hackaton['hackathon-location-description'] = unique_hack['hackathon-location-description']
final_hackaton['hackathon-location-google-maps'] = unique_hack['hackathon-location-google-maps']
final_hackaton.shape
# Out:
# (2349, 16)

# %%
final_hackaton.sample(2)
# Out:
#                            _id  \
# 1325  63854468343173ef37d045d1
# 1416  63854469343173ef37d0462c
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 hackathon-description-text  \
# 1325                                                                                                                                                                                                                                                       \nReDI is a non-profit refugee tech school aimed at accelerating refugee integration into the job market by teaching market relevant IT skills. We use tech to connect human potential and opportunity with dignity & humility.
# 1416  \nCalling all civic-minded citizens! Think your city could be better? Be it Islamabad or Rawalpindi, we have civic problems and opportunities! Do you have ideas about how to fix things? Do you like working with other intelligent people? Have skills like web or mobile development, design, mapping, data analysis, research? Want to innovate on top of government information and services? Come apply your geek or creative skills to transforming your city for the better.
#
#       hackathon-number-of-prizes            hackathon-id  \
# 1325                           5  humanitarian-hackathon
# 1416                           4            isbhacks2016
#
#       hackathon-number-of-judges hackathon-number-of-participants  \
# 1325                           6                               33
# 1416                          23                              149
#
#       hackathon-is-colocated  hackathon-has-ended  \
# 1325                    True                 True
# 1416                    True                 True
#
#       hackathon-number-of-judging-criteria  \
# 1325                                     4
# 1416                                     5
#
#                                     hackathon-url  \
# 1325  https://humanitarian-hackathon.devpost.com/
# 1416            https://isbhacks2016.devpost.com/
#
#                                                                                  hackathon-description-header  \
# 1325  Solve real-life issues that refugees and migrants are facing in the Middle East, Ukraine, and Colombia.
# 1416                                                           Islamabad Hackathon 2016 - Reshaping Islamabad
#
#      hackathon-prizes-total  has-projects  \
# 1325                 $2,762          True
# 1416             PKR225,000          True
#
#                    hackathon-location-address hackathon-location-description  \
# 1325  Am Nordbahnhof 3, 10115 Berlin, Germany                    ReDI School
# 1416  A.K.Fazl-ul-Haq Rd, Islamabad, Pakistan            The Hive, Islamabad
#
#                                           hackathon-location-google-maps
# 1325  https://maps.google.com/?q=Am Nordbahnhof 3, 10115 Berlin, Germany
# 1416  https://maps.google.com/?q=A.K.Fazl-ul-Haq Rd, Islamabad, Pakistan

# %%
final_hackaton.columns
# Out:
# Index(['_id', 'hackathon-description-text', 'hackathon-number-of-prizes',
#        'hackathon-id', 'hackathon-number-of-judges',
#        'hackathon-number-of-participants', 'hackathon-is-colocated',
#        'hackathon-has-ended', 'hackathon-number-of-judging-criteria',
#        'hackathon-url', 'hackathon-description-header',
#        'hackathon-prizes-total', 'has-projects', 'hackathon-location-address',
#        'hackathon-location-description', 'hackathon-location-google-maps'],
#       dtype='object')

# %%
# # # - Drop irrelevant columns

# %%
#final_hackaton = final_hackaton.drop('hackathon-prizes.0.prize-title', axis =1)
final_hackaton = final_hackaton.drop('hackathon-number-of-judging-criteria', axis=1)
final_hackaton = final_hackaton.drop('hackathon-location-description', axis=1)

final_hackaton.shape
# Out:
# (2349, 14)

# %%
nulls = final_hackaton.isnull().sum()
for key,value in nulls.items():
    print(key,",",value)
# Out:
# _id , 0
# hackathon-description-text , 0
# hackathon-number-of-prizes , 0
# hackathon-id , 0
# hackathon-number-of-judges , 0
# hackathon-number-of-participants , 0
# hackathon-is-colocated , 0
# hackathon-has-ended , 0
# hackathon-url , 0
# hackathon-description-header , 0
# hackathon-prizes-total , 0
# has-projects , 0
# hackathon-location-address , 484
# hackathon-location-google-maps , 484

# %%
#We delete hackatons without location

# %%
final_hackaton = final_hackaton.dropna(subset=['hackathon-location-address', 'hackathon-location-google-maps'], how = 'all')
final_hackaton.shape
# Out:
# (1865, 14)

# %%
final_hackaton = final_hackaton.dropna(subset=['hackathon-id'], how = 'all')
final_hackaton.shape
# Out:
# (1865, 14)

# %%
#final_hackaton = final_hackaton.drop(['_id'], axis=1)

# %%
final_hackaton.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1865 entries, 6 to 2346
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   _id                               1865 non-null   object
#  1   hackathon-description-text        1865 non-null   object
#  2   hackathon-number-of-prizes        1865 non-null   int64
#  3   hackathon-id                      1865 non-null   object
#  4   hackathon-number-of-judges        1865 non-null   int64
#  5   hackathon-number-of-participants  1865 non-null   object
#  6   hackathon-is-colocated            1865 non-null   bool
#  7   hackathon-has-ended               1865 non-null   bool
#  8   hackathon-url                     1865 non-null   object
#  9   hackathon-description-header      1865 non-null   object
#  10  hackathon-prizes-total            1865 non-null   object
#  11  has-projects                      1865 non-null   bool
#  12  hackathon-location-address        1865 non-null   object
#  13  hackathon-location-google-maps    1865 non-null   object
# dtypes: bool(3), int64(2), object(9)
# memory usage: 180.3+ KB

# %%
final_hackaton['hackathon-location-address'].fillna(final_hackaton['hackathon-location-google-maps'])
final_hackaton['hackathon-location-google-maps'].fillna(final_hackaton['hackathon-location-address'])
# Out:
# 6       https://maps.google.com/?q=20 N Upper Wacker Dr, Chicago, IL 60606, USA
# 7                      https://maps.google.com/?q=Callaghan NSW 2308, Australia
# 9                      https://maps.google.com/?q=Chester St, Manchester M1, UK
# 10         https://maps.google.com/?q=HKUST (South), Clear Water Bay, Hong Kong
# 11             https://maps.google.com/?q=410 Pierce St, Houston, TX 77002, USA
#                                          ...
# 2341                              https://maps.google.com/?q=Princeton, NJ, USA
# 2343                    https://maps.google.com/?q=San Francisco, CA 94105, USA
# 2344                             https://maps.google.com/?q=Calea Vitan nr 6-6a
# 2345               https://maps.google.com/?q=Calea Vitan 6, București, Romania
# 2346        https://maps.google.com/?q=1520 2nd St, Santa Monica, CA 90401, USA
# Name: hackathon-location-google-maps, Length: 1865, dtype: object

# %%
descriptions = final_hackaton[["hackathon-id", "hackathon-location-address", "hackathon-location-google-maps"]]
pd.set_option('display.max_colwidth', None)
descriptions.sample(20)
# Out:
#                        hackathon-id  \
# 1160                       hackthe6
# 1764                   pivotpoint16
# 1211                   hackucsc2017
# 182                    blairhacks-0
# 1587        microsoftenterprisehack
# 832                    hackbythesea
# 1894    seattle-vr-hackathon-5-5073
# 2272                  wearhacks-nyc
# 1769                 pnpxccnbithack
# 1622             musichackdayberlin
# 1180               hackthenorth2016
# 2137           tokyoblockshackathon
# 1880            scripted-adv-hack18
# 136                       basehacks
# 1562                   medhacks2017
# 2215                  uwphacks-4200
# 2203                 unihack2017mel
# 1140                        hacksmc
# 1563            medhacksfsummer2014
# 1694  opportunity-hack-2015-arizona
#
#                                         hackathon-location-address  \
# 1160                860 Richmond St W, Toronto, ON M6J 1C9, Canada
# 1764  Torgersen Hall, 620 Drillfield Dr, Blacksburg, VA 24061, USA
# 1211               411 Porter-Kresge Rd, Santa Cruz, CA 95064, USA
# 182             51 University Blvd E, Silver Spring, MD 20901, USA
# 1587         1133 15th Street Northwest, Washington, DC 20005, USA
# 832                       5100 Adolfo Rd, Camarillo, CA 93012, USA
# 1894          Building 5, 7543 63rd Ave NE, Seattle, WA 98115, USA
# 2272                     Metrotech Center, Brooklyn, NY 11201, USA
# 1769                440 North Wolfe Road, Sunnyvale, CA 94085, USA
# 1622                        Nalepastraße 18, 12459 Berlin, Germany
# 1180            200 University Ave W, Waterloo, ON N2L 3G5, Canada
# 2137          6 Chome-11-1 Roppongi, Minato, Tokyo 106-6108, Japan
# 1880        Pier 86, W 46th St & 12th Ave, New York, NY 10036, USA
# 136                  1020 Enterprise Way, Sunnyvale, CA 94089, USA
# 1562                     720 Rutland Ave, Baltimore, MD 21205, USA
# 2215                      106 Seagram Dr, Waterloo, ON N2L, Canada
# 2203                 271 Collins St, Melbourne VIC 3004, Australia
# 1140                  425 Broadway St, Redwood City, CA 94063, USA
# 1563                                            Palo Alto, CA, USA
# 1694                 3000 One Payment Way, Chandler, AZ 85286, USA
#
#                                                                hackathon-location-google-maps
# 1160                https://maps.google.com/?q=860 Richmond St W, Toronto, ON M6J 1C9, Canada
# 1764  https://maps.google.com/?q=Torgersen Hall, 620 Drillfield Dr, Blacksburg, VA 24061, USA
# 1211               https://maps.google.com/?q=411 Porter-Kresge Rd, Santa Cruz, CA 95064, USA
# 182             https://maps.google.com/?q=51 University Blvd E, Silver Spring, MD 20901, USA
# 1587         https://maps.google.com/?q=1133 15th Street Northwest, Washington, DC 20005, USA
# 832                       https://maps.google.com/?q=5100 Adolfo Rd, Camarillo, CA 93012, USA
# 1894          https://maps.google.com/?q=Building 5, 7543 63rd Ave NE, Seattle, WA 98115, USA
# 2272                     https://maps.google.com/?q=Metrotech Center, Brooklyn, NY 11201, USA
# 1769                https://maps.google.com/?q=440 North Wolfe Road, Sunnyvale, CA 94085, USA
# 1622                        https://maps.google.com/?q=Nalepastraße 18, 12459 Berlin, Germany
# 1180            https://maps.google.com/?q=200 University Ave W, Waterloo, ON N2L 3G5, Canada
# 2137          https://maps.google.com/?q=6 Chome-11-1 Roppongi, Minato, Tokyo 106-6108, Japan
# 1880        https://maps.google.com/?q=Pier 86, W 46th St & 12th Ave, New York, NY 10036, USA
# 136                  https://maps.google.com/?q=1020 Enterprise Way, Sunnyvale, CA 94089, USA
# 1562                     https://maps.google.com/?q=720 Rutland Ave, Baltimore, MD 21205, USA
# 2215                      https://maps.google.com/?q=106 Seagram Dr, Waterloo, ON N2L, Canada
# 2203                 https://maps.google.com/?q=271 Collins St, Melbourne VIC 3004, Australia
# 1140                  https://maps.google.com/?q=425 Broadway St, Redwood City, CA 94063, USA
# 1563                                            https://maps.google.com/?q=Palo Alto, CA, USA
# 1694                 https://maps.google.com/?q=3000 One Payment Way, Chandler, AZ 85286, USA

# %%
final_hackaton = final_hackaton[['Street', 'City', 'Code', 'Country']] = final_hackaton['hackathon-location-address'].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 final_hackaton = final_hackaton[['Street', 'City', 'Code', 'Country']] = final_hackaton['hackathon-location-address'].str.split(',', expand=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3966, in DataFrame.__setitem__(self, key, value)
#    3964     self._setitem_frame(key, value)
#    3965 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3966     self._setitem_array(key, value)
#    3967 elif isinstance(value, DataFrame):
#    3968     self._set_item_frame_value(key, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4008, in DataFrame._setitem_array(self, key, value)
#    4003 else:
#    4004     # Note: unlike self.iloc[:, indexer] = value, this will
#    4005     #  never try to overwrite values inplace
#    4007     if isinstance(value, DataFrame):
# -> 4008         check_key_length(self.columns, key, value)
#    4009         for k1, k2 in zip(key, value.columns):
#    4010             self[k1] = value[k2]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexers\utils.py:402, in check_key_length(columns, key, value)
#     400 if columns.is_unique:
#     401     if len(value.columns) != len(key):
# --> 402         raise ValueError("Columns must be same length as key")
#     403 else:
#     404     # Missing keys in columns are represented as -1
#     405     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
#Now we are going to analyze projects

# %%
projects = pd.read_csv(r"C:\Users\Usuario\Data Engineering insa\project_borrador\data\projects.csv")

# %%
projects.sample(2)
# Out:
#                            _id             hackathon-id  hackathon-winner  \
# 2637  63854472191653c462840d5c                  gearapp             False
# 2966  63854474191653c462840ea5  utscryersonlocalhackday             False
#
#       project-technologies-used project-video        project-basis  \
# 2637                          1           NaN                  NaN
# 2966                          2           NaN  with android studio
#
#                         project-technologies.0.url  \
# 2637   https://devpost.com/software/built-with/tau
# 2966  https://devpost.com/software/built-with/java
#
#      project-technologies.0.name  \
# 2637                         tau
# 2966                        java
#
#                            project-technologies.1.url  \
# 2637                                              NaN
# 2966  https://devpost.com/software/built-with/android
#
#      project-technologies.1.name project-technologies.2.url  \
# 2637                         NaN                        NaN
# 2966                     android                        NaN
#
#      project-technologies.2.name project-technologies.3.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.3.name project-technologies.4.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.4.name project-technologies.5.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.5.name project-technologies.6.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.6.name project-technologies.7.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.7.name project-technologies.8.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.8.name project-technologies.9.url  \
# 2637                         NaN                        NaN
# 2966                         NaN                        NaN
#
#      project-technologies.9.name project-technologies.10.url  \
# 2637                         NaN                         NaN
# 2966                         NaN                         NaN
#
#      project-technologies.10.name project-technologies.11.url  \
# 2637                          NaN                         NaN
# 2966                          NaN                         NaN
#
#      project-technologies.11.name project-technologies.12.url  \
# 2637                          NaN                         NaN
# 2966                          NaN                         NaN
#
#      project-technologies.12.name project-technologies.13.url  \
# 2637                          NaN                         NaN
# 2966                          NaN                         NaN
#
#      project-technologies.13.name project-technologies.14.url  \
# 2637                          NaN                         NaN
# 2966                          NaN                         NaN
#
#      project-technologies.14.name project-challenges project-future-plans  \
# 2637                          NaN                NaN                  NaN
# 2966                          NaN           too nuts        dassall folks
#
#        project-purpose                                 hackathon-url  \
# 2637               NaN                  https://gearapp.devpost.com/
# 2966  see past courses  https://utscryersonlocalhackday.devpost.com/
#
#      project-title          project-inspiration project-lessons-learned  \
# 2637     Memo Time                          NaN                     NaN
# 2966          Nutz  no data to see past courses            be less nuts
#
#      project-accomplishments  project-likes  \
# 2637                     NaN              0
# 2966         our app is nuts              2
#
#                                                      hackathon-name  \
# 2637                                     Samsung Gear App Challenge
# 2966  University of Toronto + Ryerson University MLH Local Hack Day
#
#                                                                                               project-subtitle  \
# 2637                             allows users to record audio memos at regular intervals on the Galaxy Gear 2.
# 2966  No mobile data and want to see the courses you have taken? This app makes you say, "Courses? Ha goteem!"
#
#                  project-github-url  project-number-of-comments  team-size  \
# 2637                            NaN                           0          1
# 2966  https://github.com/ozcer/Nutz                           0          4
#
#      project-creation-timestamp team.0.participant-bubble  \
# 2637  2014-07-17T17:32:31-04:00                       NaN
# 2966  2017-12-02T19:59:56-05:00                       NaN
#
#      team.0.participant-name team.0.participant-desc  \
# 2637           Tomy Varghese                     NaN
# 2966               Oscar Lin                     NaN
#
#                 team.0.participant-url team.0.participant-id  \
# 2637  https://devpost.com/tomyvarghese          tomyvarghese
# 2966         https://devpost.com/ozcer                 ozcer
#
#      team.1.participant-bubble team.1.participant-name  \
# 2637                       NaN                     NaN
# 2966                       NaN                byang123
#
#      team.1.participant-desc        team.1.participant-url  \
# 2637                     NaN                           NaN
# 2966                     NaN  https://devpost.com/byang123
#
#      team.1.participant-id team.2.participant-bubble team.2.participant-name  \
# 2637                   NaN                       NaN                     NaN
# 2966              byang123                       NaN              Jiayi Zhao
#
#      team.2.participant-desc       team.2.participant-url  \
# 2637                     NaN                          NaN
# 2966                     NaN  https://devpost.com/kamiyaa
#
#      team.2.participant-id team.3.participant-bubble team.3.participant-name  \
# 2637                   NaN                       NaN                     NaN
# 2966               kamiyaa                       NaN               Alex Wong
#
#      team.3.participant-desc        team.3.participant-url  \
# 2637                     NaN                           NaN
# 2966                     NaN  https://devpost.com/rarepep8
#
#      team.3.participant-id team.4.participant-bubble team.4.participant-name  \
# 2637                   NaN                       NaN                     NaN
# 2966              rarepep8                       NaN                     NaN
#
#      team.4.participant-desc team.4.participant-url team.4.participant-id  \
# 2637                     NaN                    NaN                   NaN
# 2966                     NaN                    NaN                   NaN
#
#      team.5.participant-bubble team.5.participant-name  \
# 2637                       NaN                     NaN
# 2966                       NaN                     NaN
#
#      team.5.participant-desc team.5.participant-url team.5.participant-id  \
# 2637                     NaN                    NaN                   NaN
# 2966                     NaN                    NaN                   NaN
#
#                                     project-url    project-id
# 2637  https://devpost.com/software/memo-time--2  memo-time--2
# 2966          https://devpost.com/software/nutz          nutz

# %%
projects.columns.tolist()
# Out:
# ['_id',
#  'hackathon-id',
#  'hackathon-winner',
#  'project-technologies-used',
#  'project-video',
#  'project-basis',
#  'project-technologies.0.url',
#  'project-technologies.0.name',
#  'project-technologies.1.url',
#  'project-technologies.1.name',
#  'project-technologies.2.url',
#  'project-technologies.2.name',
#  'project-technologies.3.url',
#  'project-technologies.3.name',
#  'project-technologies.4.url',
#  'project-technologies.4.name',
#  'project-technologies.5.url',
#  'project-technologies.5.name',
#  'project-technologies.6.url',
#  'project-technologies.6.name',
#  'project-technologies.7.url',
#  'project-technologies.7.name',
#  'project-technologies.8.url',
#  'project-technologies.8.name',
#  'project-technologies.9.url',
#  'project-technologies.9.name',
#  'project-technologies.10.url',
#  'project-technologies.10.name',
#  'project-technologies.11.url',
#  'project-technologies.11.name',
#  'project-technologies.12.url',
#  'project-technologies.12.name',
#  'project-technologies.13.url',
#  'project-technologies.13.name',
#  'project-technologies.14.url',
#  'project-technologies.14.name',
#  'project-challenges',
#  'project-future-plans',
#  'project-purpose',
#  'hackathon-url',
#  'project-title',
#  'project-inspiration',
#  'project-lessons-learned',
#  'project-accomplishments',
#  'project-likes',
#  'hackathon-name',
#  'project-subtitle',
#  'project-github-url',
#  'project-number-of-comments',
#  'team-size',
#  'project-creation-timestamp',
#  'team.0.participant-bubble',
#  'team.0.participant-name',
#  'team.0.participant-desc',
#  'team.0.participant-url',
#  'team.0.participant-id',
#  'team.1.participant-bubble',
#  'team.1.participant-name',
#  'team.1.participant-desc',
#  'team.1.participant-url',
#  'team.1.participant-id',
#  'team.2.participant-bubble',
#  'team.2.participant-name',
#  'team.2.participant-desc',
#  'team.2.participant-url',
#  'team.2.participant-id',
#  'team.3.participant-bubble',
#  'team.3.participant-name',
#  'team.3.participant-desc',
#  'team.3.participant-url',
#  'team.3.participant-id',
#  'team.4.participant-bubble',
#  'team.4.participant-name',
#  'team.4.participant-desc',
#  'team.4.participant-url',
#  'team.4.participant-id',
#  'team.5.participant-bubble',
#  'team.5.participant-name',
#  'team.5.participant-desc',
#  'team.5.participant-url',
#  'team.5.participant-id',
#  'project-url',
#  'project-id']

# %%
### Handling duplicates

# %%
projects.shape
# Out:
# (4948, 83)

# %%
duplicate = projects[projects.duplicated(['project-id'])].count()
duplicate
# Out:
# _id                          0
# hackathon-id                 0
# hackathon-winner             0
# project-technologies-used    0
# project-video                0
#                             ..
# team.5.participant-desc      0
# team.5.participant-url       0
# team.5.participant-id        0
# project-url                  0
# project-id                   0
# Length: 83, dtype: int64

# %%
#We are going to remove duplicates bases on 'hackathon-id' and'hackathon-number-of-participants' because it will make a¡our analyzis wrong.

# %%
unique_projects = projects.drop_duplicates(subset="project-id", keep='first')
#unique_projects=projects
unique_projects.shape
# Out:
# (4948, 83)

# %%
### Handling Missing Data

# %%
nullsprojects = unique_projects.isnull().sum()
for key,value in nullsprojects.items():
    print(key,",",value)
# Out:
# _id , 0
# hackathon-id , 1077
# hackathon-winner , 0
# project-technologies-used , 0
# project-video , 3994
# project-basis , 2896
# project-technologies.0.url , 1093
# project-technologies.0.name , 681
# project-technologies.1.url , 1915
# project-technologies.1.name , 1382
# project-technologies.2.url , 2482
# project-technologies.2.name , 1952
# project-technologies.3.url , 3090
# project-technologies.3.name , 2621
# project-technologies.4.url , 3625
# project-technologies.4.name , 3265
# project-technologies.5.url , 4022
# project-technologies.5.name , 3732
# project-technologies.6.url , 4314
# project-technologies.6.name , 4100
# project-technologies.7.url , 4505
# project-technologies.7.name , 4350
# project-technologies.8.url , 4649
# project-technologies.8.name , 4540
# project-technologies.9.url , 4747
# project-technologies.9.name , 4678
# project-technologies.10.url , 4828
# project-technologies.10.name , 4775
# project-technologies.11.url , 4869
# project-technologies.11.name , 4831
# project-technologies.12.url , 4897
# project-technologies.12.name , 4868
# project-technologies.13.url , 4912
# project-technologies.13.name , 4888
# project-technologies.14.url , 4919
# project-technologies.14.name , 4903
# project-challenges , 2863
# project-future-plans , 3041
# project-purpose , 2786
# hackathon-url , 1077
# project-title , 3
# project-inspiration , 2569
# project-lessons-learned , 3074
# project-accomplishments , 2984
# project-likes , 0
# hackathon-name , 1077
# project-subtitle , 554
# project-github-url , 3078
# project-number-of-comments , 0
# team-size , 0
# project-creation-timestamp , 0
# team.0.participant-bubble , 3672
# team.0.participant-name , 19
# team.0.participant-desc , 4053
# team.0.participant-url , 19
# team.0.participant-id , 19
# team.1.participant-bubble , 4297
# team.1.participant-name , 2136
# team.1.participant-desc , 4631
# team.1.participant-url , 2136
# team.1.participant-id , 2136
# team.2.participant-bubble , 4612
# team.2.participant-name , 3023
# team.2.participant-desc , 4774
# team.2.participant-url , 3023
# team.2.participant-id , 3023
# team.3.participant-bubble , 4798
# team.3.participant-name , 3860
# team.3.participant-desc , 4845
# team.3.participant-url , 3860
# team.3.participant-id , 3860
# team.4.participant-bubble , 4920
# team.4.participant-name , 4660
# team.4.participant-desc , 4921
# team.4.participant-url , 4660
# team.4.participant-id , 4660
# team.5.participant-bubble , 4944
# team.5.participant-name , 4881
# team.5.participant-desc , 4938
# team.5.participant-url , 4881
# team.5.participant-id , 4881
# project-url , 0
# project-id , 0

# %%
unique_projects = unique_projects.dropna(subset=['hackathon-id'], how = 'all')
unique_projects.shape
# Out:
# (3871, 83)

# %%
#we don't have to delete any row because of nulls because in the columns we care they don't have nulls

# %%
#we are going to drop some irrelevant columns for our analysis

# %%
final_projects = unique_projects[unique_projects.columns.drop(list(unique_projects.filter(regex='project-technologies')))]

# %%
final_projects = final_projects[final_projects.columns.drop(list(final_projects.filter(regex='participant-bubble')))]

# %%
final_projects = final_projects[final_projects.columns.drop(list(final_projects.filter(regex='participant-desc')))]

# %%
#final_projects = final_projects[final_projects.columns.drop(list(final_projects.filter(regex='participant-url')))]

# %%
final_projects = final_projects.drop(['project-video', 'project-basis', 'project-purpose', 'project-inspiration', 'project-lessons-learned'], axis=1)

final_projects.shape
# Out:
# (3871, 35)

# %%
final_projects.sample(2)
# Out:
#                            _id     hackathon-id  hackathon-winner  \
# 2565  63854471191653c462840d14  bigredhacks2015             False
# 2686  63854472191653c462840d8d          mhacks6             False
#
#                                                                                                                                                                                                                                                           project-challenges  \
# 2565                                                                                                                                                                              Tactfully manipulating the DOM commanded by video sites was frustrating. Many of them take
# 2686  Efficient utilization of image selection and processing merged poorly with older versions of the respective Unity and Oculus runtimes. Identifying which positions of images most effectively eliminated gaps in place and position of the memory-inducing indicators.
#
#                                                                                                                                                                                                                                                                                                          project-future-plans  \
# 2565                                                                                                                                                                                                      To broker a truce between content consumers and the aforesaid creators through creative manipulation of technology.
# 2686  The images users spend time studying and committing directly to memory may be given to sponsors and advertisers who provide premiums to cater towards individual user experiences. Integration into Gear VR and use of the smartphone to provide an AR experience for real life environments lie not far in the future.
#
#                              hackathon-url project-title  \
# 2565  https://bigredhacks2015.devpost.com/    Masquerade
# 2686          https://mhacks6.devpost.com/    MindPalace
#
#      project-accomplishments  project-likes      hackathon-name  \
# 2565                     NaN              5  BigRed//Hacks 2015
# 2686                     NaN              4            MHacks 6
#
#                                                                                                          project-subtitle  \
# 2565             Masquerade overlays ads on video sites with entertaining alternatives so that the creators can get paid.
# 2686  MindPalace enhances the brain's natural ability to attribute memory to places, not pages, through Oculus' immersion
#
#      project-github-url  project-number-of-comments  team-size  \
# 2565                NaN                           0          4
# 2686                NaN                           1          1
#
#      project-creation-timestamp team.0.participant-name  \
# 2565  2015-09-20T07:02:42-04:00           Sandile Keswa
# 2686  2015-09-13T14:20:02-04:00              Sam Inloes
#
#             team.0.participant-url team.0.participant-id  \
# 2565    https://devpost.com/skeswa                skeswa
# 2686  https://devpost.com/Sami1309              Sami1309
#
#      team.1.participant-name       team.1.participant-url  \
# 2565           Daniel Cadden  https://devpost.com/Shikkic
# 2686                     NaN                          NaN
#
#      team.1.participant-id team.2.participant-name  \
# 2565               Shikkic                 Waqas L
# 2686                   NaN                     NaN
#
#              team.2.participant-url team.2.participant-id  \
# 2565  https://devpost.com/xxwikkixx             xxwikkixx
# 2686                            NaN                   NaN
#
#      team.3.participant-name         team.3.participant-url  \
# 2565             John Nguyen  https://devpost.com/jnguyen23
# 2686                     NaN                            NaN
#
#      team.3.participant-id team.4.participant-name team.4.participant-url  \
# 2565             jnguyen23                     NaN                    NaN
# 2686                   NaN                     NaN                    NaN
#
#      team.4.participant-id team.5.participant-name team.5.participant-url  \
# 2565                   NaN                     NaN                    NaN
# 2686                   NaN                     NaN                    NaN
#
#      team.5.participant-id                                     project-url  \
# 2565                   NaN  https://devpost.com/software/masquerade-6ovytw
# 2686                   NaN         https://devpost.com/software/mindpalace
#
#              project-id
# 2565  masquerade-6ovytw
# 2686         mindpalace

# %%
final_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3871 entries, 1 to 4947
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         3871 non-null   object
#  1   hackathon-id                3871 non-null   object
#  2   hackathon-winner            3871 non-null   bool
#  3   project-challenges          1854 non-null   object
#  4   project-future-plans        1702 non-null   object
#  5   hackathon-url               3871 non-null   object
#  6   project-title               3869 non-null   object
#  7   project-accomplishments     1750 non-null   object
#  8   project-likes               3871 non-null   int64
#  9   hackathon-name              3871 non-null   object
#  10  project-subtitle            3409 non-null   object
#  11  project-github-url          1480 non-null   object
#  12  project-number-of-comments  3871 non-null   int64
#  13  team-size                   3871 non-null   int64
#  14  project-creation-timestamp  3871 non-null   object
#  15  team.0.participant-name     3855 non-null   object
#  16  team.0.participant-url      3855 non-null   object
#  17  team.0.participant-id       3855 non-null   object
#  18  team.1.participant-name     2546 non-null   object
#  19  team.1.participant-url      2546 non-null   object
#  20  team.1.participant-id       2546 non-null   object
#  21  team.2.participant-name     1778 non-null   object
#  22  team.2.participant-url      1778 non-null   object
#  23  team.2.participant-id       1778 non-null   object
#  24  team.3.participant-name     1009 non-null   object
#  25  team.3.participant-url      1009 non-null   object
#  26  team.3.participant-id       1009 non-null   object
#  27  team.4.participant-name     257 non-null    object
#  28  team.4.participant-url      257 non-null    object
#  29  team.4.participant-id       257 non-null    object
#  30  team.5.participant-name     58 non-null     object
#  31  team.5.participant-url      58 non-null     object
#  32  team.5.participant-id       58 non-null     object
#  33  project-url                 3871 non-null   object
#  34  project-id                  3871 non-null   object
# dtypes: bool(1), int64(3), object(31)
# memory usage: 1.0+ MB

# %%
#We can observe that Pandas is not able to infer the type on its own for the non-ID columns. So, let's enforce the type

# %%
final_projects.sample(4)
# Out:
#                            _id hackathon-id  hackathon-winner  \
# 285   63854460191653c46284042c  hackumbcf16             False
# 807   63854464191653c462840636      mchacks             False
# 2923  63854474191653c462840e7a     nistdata             False
# 3242  63854476191653c462840fb9  nshackathon             False
#
#                                                                                                                                                                                                                                                                                                                          project-challenges  \
# 285                                                                                                                                                                                                                                                                                                                                     NaN
# 807                                                                                                                                                                                                                                                                                                                                     NaN
# 2923  The biggest challenge I faced was trying to figure out what exactly the user is asking for when they pose a question to the application. The majority of my development time was spent testing and fixing my spoken word interpreter to better figure out what the user is asking, and to assemble the best possible answer for them.
# 3242                                                                                                                                                                                                                                                                                                                                    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  project-future-plans  \
# 285                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 807                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 2923  Since so much of the limited development time was spend on the speech interpreter, I'm excited to give a little more attention to NISTAssit's user interface to clean that up.\nAdditionally, since NISTAssist is an application that benefits the most by learning from a large number of users, I'm hoping to get this beta version into more hands to gauge interest in additional features such as favorites, and to build a network of related data values so that NISTAssist can better predict what a user is _ going _ to ask based on the last few items they did ask.
# 3242                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#
#                          hackathon-url                    project-title  \
# 285   https://hackumbcf16.devpost.com/  Autonomous Parallel-Parking Car
# 807       https://mchacks.devpost.com/                      CloudyBeats
# 2923     https://nistdata.devpost.com/                       NISTAssist
# 3242  https://nshackathon.devpost.com/                        PlusAlpha
#
#      project-accomplishments  project-likes                 hackathon-name  \
# 285                      NaN              1             HackUMBC Fall 2016
# 807                      NaN              0                   McHacks 2014
# 2923                     NaN              0       Reference Data Challenge
# 3242                     NaN              2  NS Hackathon @ Lehman College
#
#                                                                                                       project-subtitle  \
# 285                                                                      A car that parallel-parks itself autonomously
# 807                                                                                                                NaN
# 2923  NISTAssist is a virtual assistant that answers your spoken questions out loud using the available NIST datasets.
# 3242                                                                                                Save for even more
#
#                          project-github-url  project-number-of-comments  \
# 285                                     NaN                           0
# 807                                     NaN                           0
# 2923                                    NaN                           0
# 3242  https://github.com/dan-choe/plusAlpha                           0
#
#       team-size project-creation-timestamp team.0.participant-name  \
# 285           4  2016-10-02T11:17:44-04:00                  Arnold
# 807           2  2014-03-21T18:31:03-04:00                Will Lau
# 2923          1  2015-09-28T12:19:27-04:00     christopherzumberge
# 3242          1  2017-11-11T05:48:07-05:00                Dan Choe
#
#                        team.0.participant-url team.0.participant-id  \
# 285               https://devpost.com/Arnoldo               Arnoldo
# 807               https://devpost.com/lauyuen               lauyuen
# 2923  https://devpost.com/christopherzumberge   christopherzumberge
# 3242             https://devpost.com/dan-choe              dan-choe
#
#      team.1.participant-name         team.1.participant-url  \
# 285          Matthew Puentes  https://devpost.com/Mgpuentes
# 807                     vahe       https://devpost.com/vahe
# 2923                     NaN                            NaN
# 3242                     NaN                            NaN
#
#      team.1.participant-id team.2.participant-name  \
# 285              Mgpuentes          Ankit Baingane
# 807                   vahe                     NaN
# 2923                   NaN                     NaN
# 3242                   NaN                     NaN
#
#                  team.2.participant-url team.2.participant-id  \
# 285   https://devpost.com/ankitbaingane         ankitbaingane
# 807                                 NaN                   NaN
# 2923                                NaN                   NaN
# 3242                                NaN                   NaN
#
#      team.3.participant-name            team.3.participant-url  \
# 285            Vinay Agarwal  https://devpost.com/VinayAgarwal
# 807                      NaN                               NaN
# 2923                     NaN                               NaN
# 3242                     NaN                               NaN
#
#      team.3.participant-id team.4.participant-name team.4.participant-url  \
# 285           VinayAgarwal                     NaN                    NaN
# 807                    NaN                     NaN                    NaN
# 2923                   NaN                     NaN                    NaN
# 3242                   NaN                     NaN                    NaN
#
#      team.4.participant-id team.5.participant-name team.5.participant-url  \
# 285                    NaN                     NaN                    NaN
# 807                    NaN                     NaN                    NaN
# 2923                   NaN                     NaN                    NaN
# 3242                   NaN                     NaN                    NaN
#
#      team.5.participant-id  \
# 285                    NaN
# 807                    NaN
# 2923                   NaN
# 3242                   NaN
#
#                                                        project-url  \
# 285   https://devpost.com/software/autonomous-parallel-parking-car
# 807                       https://devpost.com/software/cloudybeats
# 2923                https://devpost.com/software/nistassist-2409fi
# 3242                        https://devpost.com/software/plusalpha
#
#                            project-id
# 285   autonomous-parallel-parking-car
# 807                       cloudybeats
# 2923                nistassist-2409fi
# 3242                        plusalpha

# %%
final_p = final_projects.melt(id_vars = ['hackathon-id', 'hackathon-winner', 'project-challenges', 'project-future-plans', 'hackathon-url', 'project-title', 'project-accomplishments', 'project-likes', 'hackathon-name', 'project-subtitle', 'project-github-url', 'project-number-of-comments', 'team-size', 'project-creation-timestamp', 'project-url', 'project-id'], value_vars = ['team.0.participant-id','team.1.participant-id', 'team.2.participant-id','team.3.participant-id','team.4.participant-id','team.5.participant-id']  ,var_name = 'team', value_name = 'participant-id')

# %%
final_p.sample()
# Out:
#         hackathon-id  hackathon-winner  \
# 14320  disruptsf2017             False
#
#                                                         project-challenges  \
# 14320  Our requests were not working due to browser security restrictions.
#
#       project-future-plans                       hackathon-url project-title  \
# 14320             The Moon  https://disruptsf2017.devpost.com/     quickText
#
#                            project-accomplishments  project-likes  \
# 14320  Getting the SMS requests to work with JSONP              2
#
#                    hackathon-name  \
# 14320  TechCrunch Disrupt SF 2017
#
#                                                  project-subtitle  \
# 14320  Browser extension for using SMS in any site for any number
#
#       project-github-url  project-number-of-comments  team-size  \
# 14320                NaN                           0          3
#
#       project-creation-timestamp                             project-url  \
# 14320  2017-09-17T12:43:57-04:00  https://devpost.com/software/quicktext
#
#       project-id                   team participant-id
# 14320  quicktext  team.3.participant-id            NaN

# %%
non_null_p = final_p.dropna(subset=['participant-id'], how = 'all')
non_null_p.shape
# Out:
# (9503, 18)

# %%
non_null_p.sample(10)
# Out:
#                          hackathon-id  hackathon-winner  \
# 5348                         hackmsit             False
# 11080                     hackru-sp17             False
# 1598                   boilermake2015             False
# 8831                          brh2017             False
# 12017            start-hack-2018-6129             False
# 7907                          hackdfw             False
# 9459   opportunity-hack-2015-san-jose              True
# 10008                      brickhack3             False
# 2578                       hackingedu             False
# 1721                          bitcamp             False
#
#                                                                                                                                                                                                                                                                                                                                                                                               project-challenges  \
# 5348                                                                                                                                                                                                                                                                           Time management was a major issue. Also, how inputs from hospitals will be taken and shown real time was a challenge to overcome.
# 11080                                                                                                                                                                                                                                                                                                                                                                                                        NaN
# 1598                                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 8831                                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 12017  Most of the project went smoothly without major challenges. One challenge was the small memory Arduino Nano offers (2k bytes). To overcome this, we transmitted short byte arrays representing the messages. All the code written is a memory efficient code. Moreover we found the integration between the IDE and the Muse server somewhat challenging. We used web sockets to overcome this challenge.
# 7907                                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 9459                                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 10008                                                                                                                                                                                                                                                                                                                                                                                                 everything
# 2578                                                                                                                                                                                                                                                            Figuring out how much I could accomplish within the limited time provided. Especially when determining how much "pokemon" I wanted to integrate.
# 1721                                                                                                                                                                                                                                                                                                                                                                                                         NaN
#
#                                                                                                                                                                                                                                                                                                                                                     project-future-plans  \
# 5348                                                                                                                                                                                                                                                                                                                                        Should be properly organized
# 11080                                                                                                                                                                                                                                                                                                                                                                NaN
# 1598                                                                                                                                                                                                                                                                                                                                                                 NaN
# 8831                                                                                                                                                                                                                                                                                                                                                                 NaN
# 12017  The next step for us is to commercialize those cans. We're going to put all the wires inside the can, and give it a clean non-hacky look and feel. Replace the 9V Battery with a rechargeable one and make it robuster with more sensors. Once we make such a can, we have basically a go-to-market product. In addition a GUI and special IDE will be developed.
# 7907                                                                                                                                                                                                                                                                                                                                                                 NaN
# 9459                                                                                                                                                                                                                                                                                                                                                                 NaN
# 10008                                                                                                                                                                                                                                                                                                                                                             steam?
# 2578                                                                                                                                                         I hope that pokemon payments can become a fully developed web application that brings young adults our age back to a nostalgic time, and takes the edge off paying the bills with exciting text and images.
# 1721                                                                                                                                                                                                                                                                                                                                                                 NaN
#
#                                              hackathon-url  \
# 5348                         https://hackmsit.devpost.com/
# 11080                     https://hackru-sp17.devpost.com/
# 1598                   https://boilermake2015.devpost.com/
# 8831                          https://brh2017.devpost.com/
# 12017            https://start-hack-2018-6129.devpost.com/
# 7907                          https://hackdfw.devpost.com/
# 9459   https://opportunity-hack-2015-san-jose.devpost.com/
# 10008                      https://brickhack3.devpost.com/
# 2578                       https://hackingedu.devpost.com/
# 1721                          https://bitcamp.devpost.com/
#
#                             project-title  \
# 5348                         MapDemic Web
# 11080            Telephone for Telephones
# 1598                              Houdini
# 8831                        ExtendedEssay
# 12017                          Breakpoint
# 7907          Around The World in 80 Days
# 9459                              InTouch
# 10008  *ALBANY*Ninjutsu Master table 20 B
# 2578                     Pokemon Payments
# 1721                               InTune
#
#                                                                                                                                                                                                                                                                                                                                                                                                project-accomplishments  \
# 5348                                                                                                                                                                                                                                                                                                                                     Completed the project in just a day without much experience. Not only were we
# 11080                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 1598                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 8831                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 12017  We started the event clueless. after 24 hours we had a breadboard with some wires and LCD screen. 2 hours later we had some graphs showing brain activity. The road to the Red Bull can you see on the picture, was fast and efficient. Controlling the IDE from across the room, as a show off, was amazing! It was stunning to see a full and functional product comes to life overnight from a Red Bull can.
# 7907                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 9459                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 10008                                                                                                                                                                                                                                                                                                                                                                                            the computer turns on
# 2578                                                                                                                                                                                                                                                                              I built the flask interface and have moved on to the python-api portion, hopefully, I can implement a working model with names soon.
# 1721                                                                                                                                                                                                                                                                                                                                                                                                               NaN
#
#        project-likes                  hackathon-name  \
# 5348               1                       Hack@MSIT
# 11080              0                      HackRU XII
# 1598               0                      BoilerMake
# 8831               1         BigRed//Hacks Fall 2017
# 12017              0                 START Hack 2018
# 7907               0                         HackDFW
# 9459               0  Opportunity Hack 2015 San Jose
# 10008              2                     BrickHack 3
# 2578               1                      HackingEDU
# 1721               0                    Bitcamp 2014
#
#                                                                                                         project-subtitle  \
# 5348                                                                                            Track diseases real time
# 11080                                                  Like the classic game telephone, but played with real telephones!
# 1598                                                                                  Escape those awkward conversations
# 8831       Python-Based language framework that utilizes multiple Private APIs to programmatically increase essay length
# 12017  Breakpoint is a fatigue sensing mechanical debugging tool that integrates with IDEs to help developers stay sane.
# 7907      Put on your holiday shoes and travel around the globe with our smart algorithmically generated world tour plan
# 9459                                                         A simple yet capable tool for staying in touch with seniors
# 10008                                                                      Imagine you can do all jutsu's like in naruto
# 2578                                                       Let's make paying the bills not only fun, but even nostalgic.
# 1721                                                                                                                 NaN
#
#                                              project-github-url  \
# 5348                        https://github.com/zerismo/hackmsit
# 11080      https://github.com/michaelsulit/telephone4telephones
# 1598                           https://github.com/Jarvl/houdini
# 8831               https://github.com/theriley106/ExtendedEssay
# 12017                             https://github.com/devThought
# 7907                                                        NaN
# 9459   https://github.com/Opportunity-Hack-2015-SanJose/InTouch
# 10008                        https://github.com/MateoV97/VRCode
# 2578                  https://github.com/daliu/pokemon_payments
# 1721                                                        NaN
#
#        project-number-of-comments  team-size project-creation-timestamp  \
# 5348                            0          3  2016-02-04T03:27:38-05:00
# 11080                           0          4  2017-04-23T10:29:26-04:00
# 1598                            0          2  2015-10-18T08:53:28-04:00
# 8831                            0          3  2017-09-17T07:04:48-04:00
# 12017                           0          4  2018-02-24T13:30:42-05:00
# 7907                            0          3  2015-03-01T13:22:43-05:00
# 9459                            0          3  2015-10-03T15:09:11-04:00
# 10008                           0          4  2017-02-11T22:06:18-05:00
# 2578                            0          2  2015-10-25T01:50:56-04:00
# 1721                            0          2  2014-04-06T10:02:27-04:00
#
#                                                     project-url  \
# 5348               https://devpost.com/software/hackmsit-7ibqa1
# 11080     https://devpost.com/software/telephone-for-telephones
# 1598                       https://devpost.com/software/houdini
# 8831                 https://devpost.com/software/extendedessay
# 12017                   https://devpost.com/software/breakpoint
# 7907   https://devpost.com/software/around-the-world-in-80-days
# 9459                https://devpost.com/software/intouch-73qoeb
# 10008                  https://devpost.com/software/naruto-game
# 2578              https://devpost.com/software/pokemon-payments
# 1721                        https://devpost.com/software/intune
#
#                         project-id                   team  participant-id
# 5348               hackmsit-7ibqa1  team.1.participant-id        MohitS10
# 11080     telephone-for-telephones  team.2.participant-id  andreadoucette
# 1598                       houdini  team.0.participant-id       luisfinke
# 8831                 extendedessay  team.2.participant-id            loui
# 12017                   breakpoint  team.3.participant-id        lguerdan
# 7907   around-the-world-in-80-days  team.2.participant-id         LINKIWI
# 9459                intouch-73qoeb  team.2.participant-id         navyamp
# 10008                  naruto-game  team.2.participant-id         ezmarte
# 2578              pokemon-payments  team.0.participant-id        davidliu
# 1721                        intune  team.0.participant-id        jscatena

# %%
joined_data = non_null_p.join(final_hackaton.set_index('hackathon-id'), how='inner', on='hackathon-id', lsuffix='_caller')

# %%
joined_data.sample(2)
# Out:
#            hackathon-id  hackathon-winner  \
# 218  csusmhackathonfa15             False
# 615          hackgt2016             False
#
#                                                                                                                                      project-challenges  \
# 218                                                        I ran into CSS alignment issues, which was fixed with the help of mentors Michael and Emily.
# 615  All those API traffic need to be done asynchronously. We wrote a plenty of ECMAScript with promise operation to handle those operations carefully.
#
#                                                                                                               project-future-plans  \
# 218  Hopefully we can work together as a team and complete our website to better the lives of foster children around the universe.
# 615                                                                          Many things to do: better UI, scalability, and so on.
#
#                         hackathon-url_caller       project-title  \
# 218  https://csusmhackathonfa15.devpost.com/  Millennium Falcare
# 615          https://hackgt2016.devpost.com/        Mock Trading
#
#                                                                                     project-accomplishments  \
# 218                    That I was able to build an entire website from scratch in a limited amount of time.
# 615  This is the first time for us to hack a full-stack project in 36 hours! We really love this hackathon.
#
#      project-likes                                     hackathon-name  \
# 218              0  Women's Hackathon CSU San Marcos October 24, 2015
# 615              1                                        HackGT 2016
#
#                                                            project-subtitle  \
# 218                        Foster care support from a galaxy far, far away.
# 615  A mock stock trading system built on top of firebase and blackrock API
#
#                           project-github-url  project-number-of-comments  \
# 218                                      NaN                           0
# 615  https://github.gatech.edu/mwen34/HackGT                           0
#
#      team-size project-creation-timestamp  \
# 218          3  2015-10-24T20:43:28-04:00
# 615          3  2016-09-25T08:42:15-04:00
#
#                                          project-url          project-id  \
# 218  https://devpost.com/software/millennium-falcare  millennium-falcare
# 615        https://devpost.com/software/mock-trading        mock-trading
#
#                       team      participant-id  \
# 218  team.0.participant-id  MillenniumFalcodes
# 615  team.1.participant-id            bitmingw
#
#              hackathon-description-text  hackathon-number-of-prizes  \
# 218                                  \n                           6
# 615  \nGeorgia Tech's Premier Hackathon                          23
#
#      hackathon-number-of-judges hackathon-number-of-participants  \
# 218                           1                               32
# 615                           1                              402
#
#      hackathon-is-colocated  hackathon-has-ended  \
# 218                    True                False
# 615                    True                 True
#
#                                hackathon-url  \
# 218  https://csusmhackathonfa15.devpost.com/
# 615          https://hackgt2016.devpost.com/
#
#                                                             hackathon-description-header  \
# 218  Join us on October 24, 2015 for the Women’s Hackathon event at Cal State San Marcos
# 615                                            36 hours, building, learning, and growing
#
#     hackathon-prizes-total  has-projects  \
# 218                      0         False
# 615                      0          True
#
#                                                                        hackathon-location-address  \
# 218  California State University San Marcos, 333 S Twin Oaks Valley Rd, San Marcos, CA 92078, USA
# 615                    Klaus Advanced Computing Building, 266 Ferst Dr NW, Atlanta, GA 30313, USA
#
#              hackathon-location-description  \
# 218  California State University San Marcos
# 615         Georgia Institute of Technology
#
#                                                                                               hackathon-location-google-maps
# 218  https://maps.google.com/?q=California State University San Marcos, 333 S Twin Oaks Valley Rd, San Marcos, CA 92078, USA
# 615                    https://maps.google.com/?q=Klaus Advanced Computing Building, 266 Ferst Dr NW, Atlanta, GA 30313, USA

# %%
joined_data.shape
# Out:
# (7896, 31)

# %%
#joined_data.to_csv('./data/output/ready_for_analysis.csv')

# %%
#Now we are going to work with Participants

# %%
participants = pd.read_csv(r"C:\Users\Usuario\Data Engineering insa\project_borrador\data\participants.csv")
participants.sample(2)
# Out:
#                            _id  participant-likes  participant-projects  \
# 1543  63854467b7f83fc15b874618                  0                     1
# 608   63854461b7f83fc15b874271                 12                     4
#
#                   participant-url   participant-name  participant-followers  \
# 1543  https://devpost.com/dsuther  Daniel Sutherland                      0
# 608   https://devpost.com/Ashpanr      Ashpan Raskar                      3
#
#               participant-location  \
# 1543      Toronto, Ontario, Canada
# 608   Mississauga, Ontario, Canada
#
#                                        participant-bio participant-id  \
# 1543                                               NaN        dsuther
# 608   I am aspiring to be successful and a great coder        Ashpanr
#
#                     participant-linkedin         participant-website  \
# 1543  https://ca.linkedin.com/in/dsuther  https://github.com/dsuther
# 608        http://LinkedIn.Com/in/Ashpan                         NaN
#
#               participant-github  participant-hackathons  \
# 1543  https://github.com/dsuther                       1
# 608    https://github.com/Ashpan                       4
#
#       participant-following  participant-number-of-skills  \
# 1543                      0                             5
# 608                       2                             7
#
#                                 participant-skills.0.url  \
# 1543     https://devpost.com/software/built-with/android
# 608   https://devpost.com/software/built-with/javascript
#
#      participant-skills.0.name  \
# 1543                   android
# 608                 javascript
#
#                                 participant-skills.1.url  \
# 1543  https://devpost.com/software/built-with/javascript
# 608         https://devpost.com/software/built-with/java
#
#      participant-skills.1.name  \
# 1543                javascript
# 608                       java
#
#                             participant-skills.2.url  \
# 1543    https://devpost.com/software/built-with/java
# 608   https://devpost.com/software/built-with/jquery
#
#      participant-skills.2.name                     participant-skills.3.url  \
# 1543                      java  https://devpost.com/software/built-with/ios
# 608                     jquery  https://devpost.com/software/built-with/css
#
#      participant-skills.3.name                       participant-skills.4.url  \
# 1543                       ios  https://devpost.com/software/built-with/html5
# 608                        css  https://devpost.com/software/built-with/html5
#
#      participant-skills.4.name  \
# 1543                     html5
# 608                      html5
#
#                              participant-skills.5.url  \
# 1543                                              NaN
# 608   https://devpost.com/software/built-with/arduino
#
#      participant-skills.5.name                      participant-skills.6.url  \
# 1543                       NaN                                           NaN
# 608                    arduino  https://devpost.com/software/built-with/c--2
#
#      participant-skills.6.name participant-skills.7.url  \
# 1543                       NaN                      NaN
# 608                         c#                      NaN
#
#      participant-skills.7.name participant-skills.8.url  \
# 1543                       NaN                      NaN
# 608                        NaN                      NaN
#
#      participant-skills.8.name participant-skills.9.url  \
# 1543                       NaN                      NaN
# 608                        NaN                      NaN
#
#      participant-skills.9.name participant-skills.10.url  \
# 1543                       NaN                       NaN
# 608                        NaN                       NaN
#
#      participant-skills.10.name participant-skills.11.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.11.name participant-skills.12.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.12.name participant-skills.13.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.13.name participant-skills.14.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.14.name participant-skills.15.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.15.name participant-skills.16.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.16.name participant-skills.17.url  \
# 1543                        NaN                       NaN
# 608                         NaN                       NaN
#
#      participant-skills.17.name          participant-twitter
# 1543                        NaN                          NaN
# 608                         NaN  https://twitter.com/Ashpanr

# %%
participants.sample(2).columns.tolist()
# Out:
# ['_id',
#  'participant-likes',
#  'participant-projects',
#  'participant-url',
#  'participant-name',
#  'participant-followers',
#  'participant-location',
#  'participant-bio',
#  'participant-id',
#  'participant-linkedin',
#  'participant-website',
#  'participant-github',
#  'participant-hackathons',
#  'participant-following',
#  'participant-number-of-skills',
#  'participant-skills.0.url',
#  'participant-skills.0.name',
#  'participant-skills.1.url',
#  'participant-skills.1.name',
#  'participant-skills.2.url',
#  'participant-skills.2.name',
#  'participant-skills.3.url',
#  'participant-skills.3.name',
#  'participant-skills.4.url',
#  'participant-skills.4.name',
#  'participant-skills.5.url',
#  'participant-skills.5.name',
#  'participant-skills.6.url',
#  'participant-skills.6.name',
#  'participant-skills.7.url',
#  'participant-skills.7.name',
#  'participant-skills.8.url',
#  'participant-skills.8.name',
#  'participant-skills.9.url',
#  'participant-skills.9.name',
#  'participant-skills.10.url',
#  'participant-skills.10.name',
#  'participant-skills.11.url',
#  'participant-skills.11.name',
#  'participant-skills.12.url',
#  'participant-skills.12.name',
#  'participant-skills.13.url',
#  'participant-skills.13.name',
#  'participant-skills.14.url',
#  'participant-skills.14.name',
#  'participant-skills.15.url',
#  'participant-skills.15.name',
#  'participant-skills.16.url',
#  'participant-skills.16.name',
#  'participant-skills.17.url',
#  'participant-skills.17.name',
#  'participant-twitter']

# %%
# # # - Drop irrelevant columns

# %%
participants = participants.drop('participant-twitter', axis =1)
participants = participants.drop('_id', axis=1)
participants = participants[participants.columns.drop(list(participants.filter(regex='participant-skills.')))]

participants.shape
# Out:
# (6032, 14)

# %%
### Handling duplicates

# %%
#We are going to remove duplicates bases on 'participant-id' because it will make our analyzis wrong.

# %%
duplicate_part = participants[participants.duplicated(['participant-id'])]
duplicate_part.shape
# Out:
# (0, 14)

# %%
unique_part = participants.drop_duplicates(subset="participant-id", keep='first')
unique_part.shape
# Out:
# (6032, 14)

# %%
### Handling Missing Data

# %%
nulls = unique_part.isnull().sum()
for key,value in nulls.items():
    print(key,",",value)
# Out:
# participant-likes , 0
# participant-projects , 0
# participant-url , 0
# participant-name , 0
# participant-followers , 0
# participant-location , 1066
# participant-bio , 5558
# participant-id , 0
# participant-linkedin , 5022
# participant-website , 3410
# participant-github , 3459
# participant-hackathons , 0
# participant-following , 0
# participant-number-of-skills , 0

# %%
#we don't have to delete any row because of nulls because in the columns we care they don't have nulls

# %%
unique_part.sample(2)
# Out:
#       participant-likes  participant-projects                 participant-url  \
# 5679                  0                     2  https://devpost.com/volitiontl
# 2007                  0                     1    https://devpost.com/gooshima
#
#      participant-name  participant-followers  \
# 5679          Tony Le                      5
# 2007         gooshima                      0
#
#                                                                                 participant-location  \
# 5679                                                                      Kitchener, Ontario, Canada
# 2007  <a target="_blank" rel="nofollow" href="https://github.com/gooshima">\n          Website\n</a>
#
#      participant-bio participant-id participant-linkedin  \
# 5679             NaN     volitiontl                  NaN
# 2007             NaN       gooshima                  NaN
#
#               participant-website           participant-github  \
# 5679                          NaN                          NaN
# 2007  https://github.com/gooshima  https://github.com/gooshima
#
#       participant-hackathons  participant-following  \
# 5679                       3                      0
# 2007                       1                      0
#
#       participant-number-of-skills
# 5679                             1
# 2007                             0

# %%
joined_data.sample(10)
# Out:
#                    hackathon-id  hackathon-winner  \
# 4902                hackmit2017             False
# 1746                hackisu-f16             False
# 761           uncommonhacks2018             False
# 4713                sbc-dh-2017             False
# 2243            hackarizona2016             False
# 9200                hackbu2018s              True
# 10936               pennapps-xv             False
# 506                    hacktrin             False
# 8372               hackucsc2017             False
# 9786   hackpsu-spring-2016-3747             False
#
#                                                                                                                                                                                                                           project-challenges  \
# 4902                                                                                                                                                                                                                                 Lots :)
# 1746                                                                                                                                                                                                                                     NaN
# 761      We had difficulty working with the different sizes of the svgs, and learning how to add features to the website. We had difficulties getting the blockchain up on the server and ensuring that everyone would be able to access it.
# 4713                                                                                                                                                                                                                                     NaN
# 2243                                                                                                                                                             Drones are hard. Also so is spherical coordinates but we figured those out.
# 9200                                                                                                                                                                                                                                     NaN
# 10936  Pacing ourselves at our first Hackathon, learning Flask and its intricacies, cleaning large amounts of data quickly, managing a team that could play to our strengths given that half of us have only taken a single intro CS course.
# 506                                                                              We had to correctly wire and program the Arduino board to detect heart pulse and muscle activity and utilize the information to make an accurate diagnosis.
# 8372                                                                                                         Android studio, learning the apis and having relatively low experience with computer vision made the learning curve very large.
# 9786                                                                                                                                                                                                                                     NaN
#
#                                                                                                                                                                                                                                                              project-future-plans  \
# 4902                                                                                                                                                                                                                                                                          NaN
# 1746                                                                                                                                                                                                                                                                          NaN
# 761                                   We want to add player transactions involving the blockchain and animals. Eg. an animal trading system. We also want to implement items and fighting mechanics with the animals as well as a functioning market to buy and sell the animals.
# 4713                                                                                                                                                                                                                                                                          NaN
# 2243                                                                                                                                                                                                                                                                          NaN
# 9200                                                                                                                                                                                                                                                                          NaN
# 10936  Expanding the usage of the demographic info we collect, further arranging/curating statistics in meaningful and impactful ways, further tying our content in to current events, adding additional information in statistic descriptions, building up our charities section
# 506                                                                                                                                     Creating further prototypes and making more accurate sensors.  We would like to expand the number of diseases that Cardio-Kit can detect.
# 8372                     We plan to add a feature to alert the user when they have neglected to wear an item for a period of time and give them options to either donate or post item for sale to Let Go as well as a calendar to estimate your future laundry date, as well as a
# 9786                                                                                                                                                                                                                                                                          NaN
#
#                                 hackathon-url_caller  \
# 4902                https://hackmit2017.devpost.com/
# 1746                https://hackisu-f16.devpost.com/
# 761           https://uncommonhacks2018.devpost.com/
# 4713                https://sbc-dh-2017.devpost.com/
# 2243            https://hackarizona2016.devpost.com/
# 9200                https://hackbu2018s.devpost.com/
# 10936               https://pennapps-xv.devpost.com/
# 506                    https://hacktrin.devpost.com/
# 8372               https://hackucsc2017.devpost.com/
# 9786   https://hackpsu-spring-2016-3747.devpost.com/
#
#                        project-title  \
# 4902                  Encrypto Magic
# 1746                  ISUHackathon16
# 761                 Crypto Creatures
# 4713                         Deliver
# 2243                        Myo Math
# 9200   HackBU2018-Fake-News-Detector
# 10936            State of the States
# 506                       Cardio Kit
# 8372                    cloudKlosett
# 9786                      Mathletics
#
#                                                                                                                                                                                                                                            project-accomplishments  \
# 4902                                                                                                                                                                                                                                                           NaN
# 1746                                                                                                                                                                                                                                                           NaN
# 761                                                                                                                              We're most proud of the working blockchain and how much progress we made on the website given this was our first time making one.
# 4713                                                                                                                                                                                                                                                           NaN
# 2243                                                                                                                                                                                 Finishing something in six hours with half of the team asleep for most of it.
# 9200                                                                                                                                                                                                                                                           NaN
# 10936                                                                                                                 Since this is the first Hackathon for all four members of our all-women team, we're really proud to have completed a project we're proud of!
# 506    We had to use a hot glue gun to construct our own sleeve and hand-sew the sleeve together.  We also soldered all the wires from the Arduino board.  We were also able to analyze two different sets of data to make a diagnosis: Muscle Activity and Pulse.
# 8372                                                                                                                                             The amount of work we put in as a team, we are extremely happy with our choice to take on a challenging category.
# 9786                                                                                                                                                                                                                                                           NaN
#
#        project-likes                            hackathon-name  \
# 4902               0                              HackMIT 2017
# 1746               0                                   HackISU
# 761                2                       Uncommon Hacks 2018
# 4713               1  Startupbootcamp Digital Health Hackathon
# 2243               1                         Hack Arizona 2016
# 9200               6                                    HackBU
# 10936              0                               PennApps XV
# 506                1                              HackTrin III
# 8372               0                            Hack UCSC 2017
# 9786               3                     HackPSU - Spring 2016
#
#                                                                                                             project-subtitle  \
# 4902   Want to make parts of your phone secure without all the negatives of encrypting the entire phone? Encrypto Magic dat.
# 1746                                                                                     Truman State Scheduler For CS Major
# 761                         We are crypto-creatures, bringing cryptocurrencies to the world with accessibility and cuteness.
# 4713                                                                                                          Expecting More
# 2243      Some people learn in a lecture halls. Others need to move with the material. We made a Myo app to help teach math.
# 9200                                               We developed a method to detect fake news articles with machine learning.
# 10936     Surprised by the election? So were we. Get in touch with the "other" parts of America through State of the States!
# 506                          A muscle and heart rate sensor that detects and diagnosis patients with heart related illnesses
# 8372                                                Seamlessly organize your wardrobe with this image recognition based app.
# 9786        We created an application that helps corollate weather with other aspects of your life (mood/spending/sales/etc)
#
#                                               project-github-url  \
# 4902                                                         NaN
# 1746                  https://github.com/lendkhoa/ISUHackathon16
# 761                                                          NaN
# 4713                   http://github.com/parnswir/golden-pancake
# 2243                  https://github.com/Rubalicious/Hackathon16
# 9200   https://github.com/cfiutak1/HackBU2018-Fake-News-Detector
# 10936     https://github.com/catherinemclean/state-of-the-states
# 506           https://github.com/Cardio-Diagnosis/Cardio-Kit.git
# 8372                                                         NaN
# 9786                       https://github.com/bbowman223/HackPSU
#
#        project-number-of-comments  team-size project-creation-timestamp  \
# 4902                            0          2  2017-09-17T10:27:21-04:00
# 1746                            0          1  2016-09-18T06:33:40-04:00
# 761                             0          4  2018-02-11T12:43:47-05:00
# 4713                            1          5  2017-06-11T05:09:13-04:00
# 2243                            1          4  2016-01-24T09:55:35-05:00
# 9200                            1          4  2018-02-11T12:01:00-05:00
# 10936                           0          3  2017-01-22T04:16:35-05:00
# 506                             0          4  2016-01-31T15:59:35-05:00
# 8372                            0          3  2017-01-21T21:25:15-05:00
# 9786                            0          4  2016-04-10T13:26:16-04:00
#
#                                                       project-url  \
# 4902                  https://devpost.com/software/encrypto-magic
# 1746                  https://devpost.com/software/isuhackathon16
# 761                 https://devpost.com/software/crypto-creatures
# 4713                         https://devpost.com/software/deliver
# 2243                        https://devpost.com/software/myo-math
# 9200   https://devpost.com/software/hackbu2018-fake-news-detector
# 10936            https://devpost.com/software/state-of-the-states
# 506                       https://devpost.com/software/cardio-kit
# 8372                   https://devpost.com/software/cloud-klosett
# 9786                      https://devpost.com/software/mathletics
#
#                           project-id                   team   participant-id  \
# 4902                  encrypto-magic  team.1.participant-id         mciesie3
# 1746                  isuhackathon16  team.0.participant-id  lendkhoadevpost
# 761                 crypto-creatures  team.0.participant-id            qijin
# 4713                         deliver  team.1.participant-id           Haitec
# 2243                        myo-math  team.0.participant-id      rubalicious
# 9200   hackbu2018-fake-news-detector  team.2.participant-id         hbrown10
# 10936            state-of-the-states  team.2.participant-id   dominiquehuang
# 506                       cardio-kit  team.0.participant-id       vaedprasad
# 8372                   cloud-klosett  team.2.participant-id     froyvalencia
# 9786                      mathletics  team.2.participant-id        nealvasan
#
#                             _id  \
# 4902   63854466343173ef37d044a5
# 1746   63854465343173ef37d04475
# 761    6385446f343173ef37d04939
# 4713   6385446d343173ef37d047f1
# 2243   63854464343173ef37d043b1
# 9200   63854464343173ef37d043e2
# 10936  6385446b343173ef37d0476d
# 506    63854467343173ef37d04553
# 8372   63854467343173ef37d0455f
# 9786   63854466343173ef37d044ee
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       hackathon-description-text  \
# 4902                                                                                                                                                                                                                                                                                                                                                                                                                                 \nHackMIT is MIT’s largest hackathon. Over a 24-hour period from September 16 to 17, 1,000 hackers from around the world will gather on MIT’s campus to experiment and innovate on software and hardware projects. This is your weekend to dust off old ideas or try something completely new. Imagine the craziest projects possible, and work on the hack of your dreams!
# 1746                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \nWe’re a 36 hour event hosted at Iowa State University where college students from around the
# 761                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \nis a weekend-long celebration of technology where college students from everywhere come to Chicago to make fun, random, and innovative tech-related projects with friends old and new. you’ll work in a small team to design and build a creative project from start to finish in a weekend, learning and having fun in the process.
# 4713                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  \nWelcome to the Startupbootcamp Digital Health Hackathon!
# 2243                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                \n is about bringing together the most talented students to represent the burgeoning tech ecosystem appearing across the country and creating a world class hacker culture in the southwest.
# 9200                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               \nLearn something new and build something cool this weekend. We have tons of food and swag for hackers and some amazing talks from our sponsors. Check out our hackathon page
# 10936                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        \n is scheduled for
# 506                                                                                                                                                                                                                   \nHackTrin is in its third year, and is excited to welcome students to our hackathon! HackTrin is a programming competition that encourages collaboration and innovation. Mentors will be on site to help students build applications around our theme of wellness and fitness. This is a perfect time for students to further their exploration of both software and hardware - creating anything from a mobile mileage tracking app to hardware hacks that log and analyze vital signs to help students stay fit. We plan on having hardware on site (available hardware can be found at
# 8372   \nHack UCSC is proud to announce its fourth annual hackathon, taking place on January 20 to 22, 2017. It will be held at the Porter Dining Hall, with other classrooms available throughout the event. Friday will consist of registering, eating, listening to the opening speakers, and meeting fellow Hack UCSC attendees. At midnight, hacking begins and will continue until code freeze at midnight Saturday (with meals throughout the weekend, of course!). On Sunday there will be two rounds of judging, followed by the closing speakers and announcement of the winners! This is a great opportunity to meet people interested in the same kinds of software development as you, as well as those with an entirely different set of interests, form teams, and create your very own projects!
# 9786                                                                                                                                                                                                                                                                                                                                                                        \nOn April 9th, five-hundred students from across the region will come together for 24 hours of creation, innovation and fun. Anyone is welcome to join, from seasoned coding veterans to first-time hackers from any major or field. Discover how you can create change by developing technology to solve real world problems, get mentored by industry professionals, and enjoy tons of free food, free stuff, and awesome prizes!
#
#        hackathon-number-of-prizes  hackathon-number-of-judges  \
# 4902                           34                           1
# 1746                           18                           1
# 761                             7                           1
# 4713                            5                           8
# 2243                           25                          94
# 9200                           12                           1
# 10936                          21                           1
# 506                             3                           3
# 8372                           12                           1
# 9786                           18                           3
#
#       hackathon-number-of-participants  hackathon-is-colocated  \
# 4902                               441                    True
# 1746                               204                    True
# 761                                141                    True
# 4713                                37                    True
# 2243                               323                    True
# 9200                                96                    True
# 10936                              606                    True
# 506                                 38                    True
# 8372                               341                    True
# 9786                               106                    True
#
#        hackathon-has-ended                                  hackathon-url  \
# 4902                  True               https://hackmit2017.devpost.com/
# 1746                 False               https://hackisu-f16.devpost.com/
# 761                   True         https://uncommonhacks2018.devpost.com/
# 4713                  True               https://sbc-dh-2017.devpost.com/
# 2243                  True           https://hackarizona2016.devpost.com/
# 9200                  True               https://hackbu2018s.devpost.com/
# 10936                 True               https://pennapps-xv.devpost.com/
# 506                  False                  https://hacktrin.devpost.com/
# 8372                  True              https://hackucsc2017.devpost.com/
# 9786                 False  https://hackpsu-spring-2016-3747.devpost.com/
#
#                                                                               hackathon-description-header  \
# 4902                                   Hack, build, and innovate at MIT's largest hackathon. Sept 16 - 17.
# 1746                                                                       The Midwest's Premier Hackathon
# 761                                                            Hack uncommon. Think uncommon. Be uncommon.
# 4713                                                             What type of legacy do you want to leave?
# 2243                                                                    Largest Hackathon in the Southwest
# 9200                                                                       What can you build in 24 hours?
# 10936                                                                                             Ad Astra
# 506    Trinity School's Third Annual Hackathon! Come spend a day coding in the greatest city in the world!
# 8372                                                               The premier hackathon at UC Santa Cruz!
# 9786                                                              Penn State's premiere 24 hour hackathon!
#
#       hackathon-prizes-total  has-projects  \
# 4902                 $67,050          True
# 1746                  $3,760         False
# 761                        0          True
# 4713                 $13,500          True
# 2243                  $2,520          True
# 9200                  $1,760          True
# 10936                $51,340          True
# 506                     $580         False
# 8372                 $95,500          True
# 9786                 $11,675         False
#
#                                                     hackathon-location-address  \
# 4902   Stratton Student Center, 84 Massachusetts Ave, Cambridge, MA 02139, USA
# 1746                                       2710 S Loop Dr, Ames, IA 50010, USA
# 761                                     1452 E 53rd St, Chicago, IL 60615, USA
# 4713                                 Friedrichstraße 68, 10117 Berlin, Germany
# 2243                                 744 N Highland Ave, Tucson, AZ 85719, USA
# 9200                                  85 Murray Hill Rd, Vestal, NY 13850, USA
# 10936                               220 S 33rd St, Philadelphia, PA 19104, USA
# 506                                     101 W 91st St, New York, NY 10024, USA
# 8372                           411 Porter-Kresge Rd, Santa Cruz, CA 95064, USA
# 9786                           Business Building, State College, PA 16803, USA
#
#                                                                            hackathon-location-google-maps
# 4902   https://maps.google.com/?q=Stratton Student Center, 84 Massachusetts Ave, Cambridge, MA 02139, USA
# 1746                                       https://maps.google.com/?q=2710 S Loop Dr, Ames, IA 50010, USA
# 761                                     https://maps.google.com/?q=1452 E 53rd St, Chicago, IL 60615, USA
# 4713                                 https://maps.google.com/?q=Friedrichstraße 68, 10117 Berlin, Germany
# 2243                                 https://maps.google.com/?q=744 N Highland Ave, Tucson, AZ 85719, USA
# 9200                                  https://maps.google.com/?q=85 Murray Hill Rd, Vestal, NY 13850, USA
# 10936                               https://maps.google.com/?q=220 S 33rd St, Philadelphia, PA 19104, USA
# 506                                     https://maps.google.com/?q=101 W 91st St, New York, NY 10024, USA
# 8372                           https://maps.google.com/?q=411 Porter-Kresge Rd, Santa Cruz, CA 95064, USA
# 9786                           https://maps.google.com/?q=Business Building, State College, PA 16803, USA

# %%
rows = unique_part.loc[unique_part['participant-id'] == 'dominiquehuang']
rows
# Out:
# Empty DataFrame
# Columns: [participant-likes, participant-projects, participant-url, participant-name, participant-followers, participant-location, participant-bio, participant-id, participant-linkedin, participant-website, participant-github, participant-hackathons, participant-following, participant-number-of-skills]
# Index: []

# %%
unique_part.columns
# Out:
# Index(['participant-likes', 'participant-projects', 'participant-url',
#        'participant-name', 'participant-followers', 'participant-location',
#        'participant-bio', 'participant-id', 'participant-linkedin',
#        'participant-website', 'participant-github', 'participant-hackathons',
#        'participant-following', 'participant-number-of-skills'],
#       dtype='object')

# %%
joined_data_0= pd.merge(joined_data, unique_part, left_on='participant-id' , right_on='participant-id')
#joined_data_0= joined_data.join ( unique_part.set_index( [ 'participant-id' ], verify_integrity=True ),
 #              on=[ 'participant-id' ], how='right' )

joined_data_0.sample()
# Out:
#     hackathon-id  hackathon-winner project-challenges project-future-plans  \
# 271    hackfsu15             False                NaN                  NaN
#
#                hackathon-url_caller project-title project-accomplishments  \
# 271  https://hackfsu15.devpost.com/    instagroup                     NaN
#
#      project-likes hackathon-name         project-subtitle project-github-url  \
# 271              0     HackFSU 15  instagrouping the world                NaN
#
#      project-number-of-comments  team-size project-creation-timestamp  \
# 271                           0          4  2015-03-22T06:18:35-04:00
#
#                                        project-url        project-id  \
# 271  https://devpost.com/software/instagroup-lf9di  instagroup-lf9di
#
#                       team participant-id                       _id  \
# 271  team.1.participant-id   getGirlsInIT  63854465343173ef37d0443a
#
#                                                                                          hackathon-description-text  \
# 271  \nHackFSU '15 is a hackathon where students will spend 30 hours collaborating and building incredible things.
#
#      hackathon-number-of-prizes  hackathon-number-of-judges  \
# 271                           7                           1
#
#     hackathon-number-of-participants  hackathon-is-colocated  \
# 271                              100                    True
#
#      hackathon-has-ended                   hackathon-url  \
# 271                 True  https://hackfsu15.devpost.com/
#
#             hackathon-description-header hackathon-prizes-total  has-projects  \
# 271  Culture. Code. Create. HackFSU '15.                      0          True
#
#                                                         hackathon-location-address  \
# 271  Florida State University, 600 West College Avenue, Tallahassee, FL 32306, USA
#
#                                                                                hackathon-location-google-maps  \
# 271  https://maps.google.com/?q=Florida State University, 600 West College Avenue, Tallahassee, FL 32306, USA
#
#      participant-likes  participant-projects  \
# 271                  0                     2
#
#                       participant-url participant-name  participant-followers  \
# 271  https://devpost.com/getGirlsInIT     Deja Lindsey                      2
#
#                     participant-location participant-bio  \
# 271  Tallahassee, Florida, United States             NaN
#
#                     participant-linkedin     participant-website  \
# 271  http://linkedin.com/in/dejallindsey  https://dejalindsey.me
#
#                   participant-github  participant-hackathons  \
# 271  https://github.com/Getgirlsinit                       2
#
#      participant-following  participant-number-of-skills
# 271                      1                             4

# %%
joined_data_0.shape
# Out:
# (334, 44)

# %%
joined_data_0.dropna(subset=['hackathon-location-address', 'hackathon-location-google-maps'], how = 'all')
joined_data_0.shape
# Out:
# (334, 44)

# %%
#import numpy as np
#joined_data_0['participant-number-of-skills'].fillna(value=np.random.randint(3, 16), inplace=True)

# %%
joined_data_0 = joined_data_0.drop('project-challenges', axis=1)
joined_data_0 = joined_data_0.drop('project-future-plans', axis=1)
joined_data_0 = joined_data_0.drop('project-accomplishments', axis=1)
joined_data_0 = joined_data_0.drop('hackathon-description-text', axis=1)

# %%
joined_data_0.sample(10)
# Out:
#                    hackathon-id  hackathon-winner  \
# 6                       hacksmc             False
# 234                     hackuci             False
# 34                   hackrice-7             False
# 318               cruzhacks2018              True
# 297             enghackfall2014             False
# 205            scarlethacks2017             False
# 198             dragonhacks2018              True
# 242                 hackdfw2016             False
# 35              hackatbrown2016             False
# 200  cuny-spring-hackathon-2018             False
#
#                                 hackathon-url_caller  \
# 6                       https://hacksmc.devpost.com/
# 234                     https://hackuci.devpost.com/
# 34                   https://hackrice-7.devpost.com/
# 318               https://cruzhacks2018.devpost.com/
# 297             https://enghackfall2014.devpost.com/
# 205            https://scarlethacks2017.devpost.com/
# 198             https://dragonhacks2018.devpost.com/
# 242                 https://hackdfw2016.devpost.com/
# 35              https://hackatbrown2016.devpost.com/
# 200  https://cuny-spring-hackathon-2018.devpost.com/
#
#                                        project-title  project-likes  \
# 6                                  17-Resume Builder              1
# 234                                 Sitcom Simulator              0
# 34                              Amazon price checker              0
# 318  Single Nucleotide Polymorphism Simulator (SNPS)              2
# 297                                        MyoCanvas              0
# 205                                         FoodHack              2
# 198                                            iCane              2
# 242              ourhack.dreaminfinitely.comJam Sesh              1
# 35                                        Dine Today              0
# 200                                          SleepEZ              5
#
#                                            hackathon-name  \
# 6                                                Hack-SMC
# 234                                   HackUCI Spring 2014
# 34                                             HackRice 7
# 318                                        CruzHacks 2018
# 297                                     EngHack Fall 2014
# 205  ScarletHacks 2017: Illinois Tech's Premier Hackathon
# 198                                      DragonHacks 2018
# 242                                          HackDFW 2016
# 35                                        Hack@Brown 2016
# 200                                        CUNY Hackathon
#
#                                                                                                           project-subtitle  \
# 6                                                              A step by step resume builder for those with no experience.
# 234                                                                                  Sitcom Audience Reaction in Real Life
# 34                                                                   An attempt to price check amazon and alibaba products
# 318  Simulates mutations during cell reproduction in hazardous, isolated environments to visualize the evolution of cells.
# 297                                                                                 Draw anytime, anywhere, with MyoCanvas
# 205                                                                                 IOS app pre-order food before dine-in.
# 198           Mobile Application to assist visually impaired in navigating indoor spaces as well as an improved white cane
# 242                                                                       A web app for musicians to get together and Jam!
# 35                                                                                   Find last-minute deals on restaurants
# 200                              SleepEZ, designed to help those without access to the internet, to find a place to sleep.
#
#                                      project-github-url  \
# 6                                                   NaN
# 234                                                 NaN
# 34             https://github.com/johnathanachen/MHL_18
# 318          https://github.com/joeyster/SQODCruzHack18
# 297                                                 NaN
# 205                                                 NaN
# 198              https://github.com/pixelyunicorn/icane
# 242                                                 NaN
# 35                                                  NaN
# 200  https://github.com/j-falcon122/CUNY-Hackathon-2018
#
#      project-number-of-comments  team-size project-creation-timestamp  \
# 6                             0          3  2016-05-21T16:21:44-04:00
# 234                           0          4  2014-05-25T13:01:17-04:00
# 34                            0          2  2017-09-24T06:36:22-04:00
# 318                           0          3  2018-01-20T14:11:32-05:00
# 297                           0          4  2014-11-02T13:27:10-05:00
# 205                           0          3  2017-11-12T11:00:45-05:00
# 198                           0          4  2018-01-07T10:11:54-05:00
# 242                           0          4  2016-04-17T12:23:32-04:00
# 35                            0          2  2016-02-08T11:44:51-05:00
# 200                           0          5  2018-04-30T15:55:00-04:00
#
#                                                                            project-url  \
# 6                                                      https://devpost.com/software/17
# 234                                      https://devpost.com/software/sitcom-simulator
# 34                                   https://devpost.com/software/amazon-price-checker
# 318  https://devpost.com/software/single-nucleotide-polymorphism-simulator-snps-sd3q7e
# 297                                             https://devpost.com/software/myocanvas
# 205                                              https://devpost.com/software/foodhack
# 198                                                 https://devpost.com/software/icane
# 242                                              https://devpost.com/software/jam-sesh
# 35                                             https://devpost.com/software/dine-today
# 200                                   https://devpost.com/software/cuny-hackathon-2018
#
#                                                project-id  \
# 6                                                      17
# 234                                      sitcom-simulator
# 34                                   amazon-price-checker
# 318  single-nucleotide-polymorphism-simulator-snps-sd3q7e
# 297                                             myocanvas
# 205                                              foodhack
# 198                                                 icane
# 242                                              jam-sesh
# 35                                             dine-today
# 200                                   cuny-hackathon-2018
#
#                       team  participant-id                       _id  \
# 6    team.1.participant-id         buy_one  63854467343173ef37d04518
# 234  team.1.participant-id       Vitamintk  63854467343173ef37d0455a
# 34   team.1.participant-id  johnathanachen  63854466343173ef37d044f7
# 318  team.2.participant-id    BarbosaJones  63854461343173ef37d0421c
# 297  team.2.participant-id            rlai  63854462343173ef37d042be
# 205  team.2.participant-id       ehrenbeck  6385446d343173ef37d047fa
# 198  team.0.participant-id         amma9cp  63854462343173ef37d04292
# 242  team.3.participant-id      TruthSayer  63854465343173ef37d04410
# 35   team.0.participant-id     lizzyaustad  63854464343173ef37d043b3
# 200  team.0.participant-id     j-falcon122  63854461343173ef37d04231
#
#      hackathon-number-of-prizes  hackathon-number-of-judges  \
# 6                             5                           8
# 234                          13                           0
# 34                           22                           1
# 318                          17                          27
# 297                           2                           0
# 205                          17                          11
# 198                          12                          14
# 242                           5                           6
# 35                           13                           5
# 200                           9                           8
#
#     hackathon-number-of-participants  hackathon-is-colocated  \
# 6                                 71                    True
# 234                              120                    True
# 34                               179                    True
# 318                              319                    True
# 297                               70                    True
# 205                              136                    True
# 198                              131                    True
# 242                              346                    True
# 35                               261                    True
# 200                              408                    True
#
#      hackathon-has-ended                                    hackathon-url  \
# 6                  False                     https://hacksmc.devpost.com/
# 234                 True                     https://hackuci.devpost.com/
# 34                  True                  https://hackrice-7.devpost.com/
# 318                 True               https://cruzhacks2018.devpost.com/
# 297                False             https://enghackfall2014.devpost.com/
# 205                 True            https://scarlethacks2017.devpost.com/
# 198                 True             https://dragonhacks2018.devpost.com/
# 242                 True                 https://hackdfw2016.devpost.com/
# 35                  True             https://hackatbrown2016.devpost.com/
# 200                 True  https://cuny-spring-hackathon-2018.devpost.com/
#
#                                                                                                                               hackathon-description-header  \
# 6                                                                Create solutions that help improve the lives people who live and work in San Mateo County
# 234                                                                                                                     Premier hackathon in Orange County
# 34                                                                                                                    For the night owls and the dreamers.
# 318  CruzHacks brings together a diverse and inclusive group of students and professionals to develop innovative solutions to solve real world challenges.
# 297                                                                                           A Hackathon for University of Waterloo Engineering students.
# 205                                                                                                                    ScarletHacks 2017: Soar New Heights
# 198                                                                                                            The Best 24-Hour Hardware Focused Hackathon
# 242                                                                                                               The design-thinking hackathon of Dallas.
# 35                                                                                                                          A different kind of hackathon.
# 200                                                                                                       Work together on a team to build something cool.
#
#     hackathon-prizes-total  has-projects  \
# 6                  $14,308         False
# 234                 $2,900          True
# 34                 $10,880          True
# 318                $23,375          True
# 297                   $600         False
# 205                 $5,298          True
# 198                $10,050          True
# 242                $25,000          True
# 35                       0          True
# 200                 $4,795          True
#
#                                                                         hackathon-location-address  \
# 6                                                     425 Broadway St, Redwood City, CA 94063, USA
# 234                                                   1691 Kettering Street, Irvine, CA 92614, USA
# 34                                                           Laboratory Rd, Houston, TX 77005, USA
# 318                                                411 Porter-Kresge Rd, Santa Cruz, CA 95064, USA
# 297  Chemistry 2, University of Waterloo, 200 University Avenue West, Waterloo, ON N2L 3G1, Canada
# 205                                                      3241 S Federal St, Chicago, IL 60616, USA
# 198                                        LeBow Hall, 3220 Market St, Philadelphia, PA 19104, USA
# 242                                                         1135 S Lamar St, Dallas, TX 75215, USA
# 35                                                          Sayles Hall, Providence, RI 02912, USA
# 200                                                         151 E 25th St, New York, NY 10010, USA
#
#                                                                                                hackathon-location-google-maps  \
# 6                                                     https://maps.google.com/?q=425 Broadway St, Redwood City, CA 94063, USA
# 234                                                   https://maps.google.com/?q=1691 Kettering Street, Irvine, CA 92614, USA
# 34                                                           https://maps.google.com/?q=Laboratory Rd, Houston, TX 77005, USA
# 318                                                https://maps.google.com/?q=411 Porter-Kresge Rd, Santa Cruz, CA 95064, USA
# 297  https://maps.google.com/?q=Chemistry 2, University of Waterloo, 200 University Avenue West, Waterloo, ON N2L 3G1, Canada
# 205                                                      https://maps.google.com/?q=3241 S Federal St, Chicago, IL 60616, USA
# 198                                        https://maps.google.com/?q=LeBow Hall, 3220 Market St, Philadelphia, PA 19104, USA
# 242                                                         https://maps.google.com/?q=1135 S Lamar St, Dallas, TX 75215, USA
# 35                                                          https://maps.google.com/?q=Sayles Hall, Providence, RI 02912, USA
# 200                                                         https://maps.google.com/?q=151 E 25th St, New York, NY 10010, USA
#
#      participant-likes  participant-projects  \
# 6                    0                     1
# 234                  5                     9
# 34                   1                     1
# 318                  0                     1
# 297                  2                     5
# 205                  0                     1
# 198                  9                    19
# 242                  0                     3
# 35                   1                     2
# 200                  1                     1
#
#                         participant-url   participant-name  \
# 6           https://devpost.com/buy_one       Baiwen Huang
# 234       https://devpost.com/Vitamintk         Kevin Wang
# 34   https://devpost.com/johnathanachen     Johnathan Chen
# 318    https://devpost.com/BarbosaJones       BarbosaJones
# 297            https://devpost.com/rlai         Robert Lai
# 205       https://devpost.com/ehrenbeck          ehrenbeck
# 198         https://devpost.com/amma9cp    Ammar Al-Kahfah
# 242      https://devpost.com/TruthSayer  Brandon Bielefeld
# 35      https://devpost.com/lizzyaustad       Lizzy Austad
# 200     https://devpost.com/j-falcon122      Jordan Falcon
#
#      participant-followers  \
# 6                        0
# 234                      3
# 34                       0
# 318                      1
# 297                      2
# 205                      0
# 198                     26
# 242                      1
# 35                       0
# 200                      0
#
#                                                                                 participant-location  \
# 6                                                                                                NaN
# 234                                                             Claremont, California, United States
# 34                                                          San Francisco, California, United States
# 318                                                           Los Angeles, California, United States
# 297                                                                        Waterloo, Ontario, Canada
# 205  <a target="_blank" rel="nofollow" href="https://github.com/ehrenbeck">\n          Website\n</a>
# 198                                                               Annandale, Virginia, United States
# 242                                                            Daytona Beach, Florida, United States
# 35          <a target="_blank" rel="nofollow" href="http://lizzyaustad.me">\n          Website\n</a>
# 200                                                                New York, New York, United States
#
#     participant-bio                     participant-linkedin  \
# 6               NaN                                      NaN
# 234             NaN                                      NaN
# 34              NaN                                      NaN
# 318             NaN                                      NaN
# 297             NaN                                      NaN
# 205             NaN                                      NaN
# 198             NaN                                      NaN
# 242             NaN                                      NaN
# 35              NaN  https://www.linkedin.com/in/lizzyaustad
# 200             NaN                                      NaN
#
#                  participant-website                 participant-github  \
# 6                                NaN                                NaN
# 234     https://github.com/VitamintK       https://github.com/VitamintK
# 34                 http://Jcswift.me  https://github.com/johnathanachen
# 318  https://github.com/BarbosaJones    https://github.com/BarbosaJones
# 297                              NaN       https://github.com/robertlai
# 205     https://github.com/ehrenbeck       https://github.com/ehrenbeck
# 198                              NaN                                NaN
# 242    https://github.com/TruthSayer      https://github.com/TruthSayer
# 35             http://lizzyaustad.me     https://github.com/lizzyaustad
# 200   https://github.com/j-falcon122     https://github.com/j-falcon122
#
#      participant-hackathons  participant-following  \
# 6                         1                      0
# 234                       7                      0
# 34                        1                      0
# 318                       2                      2
# 297                       6                      0
# 205                       1                      0
# 198                      25                     27
# 242                       3                      1
# 35                        2                      2
# 200                       1                      0
#
#      participant-number-of-skills
# 6                               1
# 234                             3
# 34                              2
# 318                             5
# 297                             7
# 205                             3
# 198                            10
# 242                             9
# 35                              7
# 200                             3
